# %% [markdown]
# # La Commune de Paris 1871 en liberté - Faire une requête sur wikidata en Python

# %% [markdown]
# Ce chapitre documente un point technique important pour la suite. Il explique comment le code fonctionne, et n'interroge pas la pertinance des choix de la requête. Cela est vu à d'autres moment.
#
# L'exemple est pris sur la recherche des communard·e·s présent·e·s dans Wikidata. L'explication de qu'est ce qu'un·e "communard·e·s présent·e·s dans Wikidata" sera vu plus loin.
#
# ### Méthode
#
# La classe Extraction_wikidata, est une adaption du modèle de réquête en python qui se trouve sur https://query.wikidata.org/
#
# - dans la variable query, il faut copier/coller la requête faite dans query.wikidata.org
# - exécuter les cellules "## 0" à "## 5" comme si dessous afin d'obtenir le résultat dans un dataframe exploitable pour faire des manipulations de données.
#
# Cela est reproductible, et l'est à de nombreuses occurence dans le document, sur plusieurs requêtes.
# Il suffit de changer la valeur de query (en ## 1) puis personnaliser les ##4 et 5 pour obtenir un tableau (dataframe) exploitable.

# %%
# les installations nécessaires
#https://rdflib.github.io/sparqlwrapper/
#!pip install sparqlwrapper
#!pip install seaborn

# %%
## 0 - import
import sys

from SPARQLWrapper import SPARQLWrapper, JSON

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import HTML

# %%
## 1 - les variables
endpoint_url:str = "https://query.wikidata.org/sparql"

# %%
query:str = """SELECT ?communard_ou_communarde ?communard_ou_communardeLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],fr". }
  # ?communard_ou_communarde wdt:P106 wd:Q1780490.
}"""

# %%
## 2 - l'objet
class Extraction_wikidata():
    def __init__(self, endpoint_url:str, query:str):
        self.endpoint_url:str = endpoint_url
        self.query:str = query
        
    def get_results(self, endpoint_url:str, query:str):
        user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
        # TODO adjust user agent; see https://w.wiki/CX6
        sparql = SPARQLWrapper(endpoint_url, agent = user_agent)
        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)
        return sparql.query().convert()
    
    def json_to_df(self, entree):
        #results = sparql.query().convert()
        df_results = pd.json_normalize(entree["results"]["bindings"])
        return df_results
    
    def extraire_et_df(self):
        extract_json = self.get_results(self.endpoint_url, self.query)
        extract_df = self.json_to_df(extract_json)
        return extract_df

# %%
## 3 - instantiation de l'objet et récupération du df
extraction_communard = Extraction_wikidata(endpoint_url, query)
df_communard = extraction_communard.extraire_et_df()

# %%
## 4 - afficher le df voulu
print(df_communard)
# Out:
#     communard_ou_communarde.type              communard_ou_communarde.value  \
# 0                            uri      http://www.wikidata.org/entity/Q20951
# 1                            uri      http://www.wikidata.org/entity/Q34618
# 2                            uri     http://www.wikidata.org/entity/Q184535
# 3                            uri     http://www.wikidata.org/entity/Q216092
# 4                            uri     http://www.wikidata.org/entity/Q257950
# ..                           ...                                        ...
# 304                          uri  http://www.wikidata.org/entity/Q123735409
# 305                          uri  http://www.wikidata.org/entity/Q123735410
# 306                          uri  http://www.wikidata.org/entity/Q123735411
# 307                          uri  http://www.wikidata.org/entity/Q123735412
# 308                          uri  http://www.wikidata.org/entity/Q123735413
#
#     communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 0                                      fr                           literal
# 1                                      fr                           literal
# 2                                      fr                           literal
# 3                                      fr                           literal
# 4                                      fr                           literal
# ..                                    ...                               ...
# 304                                    fr                           literal
# 305                                    fr                           literal
# 306                                    fr                           literal
# 307                                    fr                           literal
# 308                                    fr                           literal
#
#     communard_ou_communardeLabel.value
# 0                        Élisée Reclus
# 1                      Gustave Courbet
# 2                   Sofia Kovalevskaïa
# 3                        Louise Michel
# 4          Auguste-Jean-Marie Vermorel
# ..                                 ...
# 304                      Pierre Le Bos
# 305                  Mathurin Ollivier
# 306                 Jean-Marie Prigent
# 307                    Guillaume Rault
# 308                        Joseph Noel
#
# [309 rows x 5 columns]

# %%
## 5 - quelques statistiques sur le df
#df_communard.describe()

# %%
#df_communard_en_html = df_communard.to_html(columns = ['communard_ou_communarde.value', 'communard_ou_communardeLabel.value'])
#HTML(df_communard_en_html)

# %% [markdown]
# ### Avoir TOUTES les informations sur les communard·e·s

# %% [markdown]
# Cette requête, qui fonctionne comme expliqué ci dessus est importante. Car en plus de charger toutes les personnes concernées (leur label) elle récupére toutes les données liées à leur élément.
#
# Ce dataframe sera ré-utilisé à de nombreuses occasions.
#
# Pour toutes les personnes, chercher les ?p ?q avec gestion des labels.
# Attention : c'est lourd !

# %% [markdown]
# #### Aller chercher les valeurs et les mettre dans un dataframe (df) nommé df_communard_tous_p_q

# %%
query = """SELECT ?communard_ou_communarde ?communard_ou_communardeLabel ?p ?pLabel ?q ?qLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "fr,en".
                         # ?communard_ou_communarde rdfs:label ?communard_ou_communardeLabel.
                         # ?p rdfs:label ?pLabel.
                         # ?q rdfs:label ?qLabel.}
  
  # ?communard_ou_communarde wdt:P106 wd:Q1780490;
                           # ?p ?q. 
}
"""

# %%
extraction_communard_tous_p_q = Extraction_wikidata(endpoint_url, query)
df_communard_tous_p_q = extraction_communard_tous_p_q.extraire_et_df()

# %%
df_communard_tous_p_q
# Out:
#       communard_ou_communarde.type            communard_ou_communarde.value  \
# 0                              uri    http://www.wikidata.org/entity/Q20951
# 1                              uri    http://www.wikidata.org/entity/Q20951
# 2                              uri    http://www.wikidata.org/entity/Q20951
# 3                              uri    http://www.wikidata.org/entity/Q20951
# 4                              uri    http://www.wikidata.org/entity/Q20951
# ...                            ...                                      ...
# 34314                          uri  http://www.wikidata.org/entity/Q3035446
# 34315                          uri  http://www.wikidata.org/entity/Q3035446
# 34316                          uri  http://www.wikidata.org/entity/Q3035446
# 34317                          uri  http://www.wikidata.org/entity/Q3035446
# 34318                          uri  http://www.wikidata.org/entity/Q3035446
#
#       p.type                                       p.value q.xml:lang  \
# 0        uri  http://www.w3.org/2004/02/skos/core#altLabel         oc
# 1        uri  http://www.w3.org/2004/02/skos/core#altLabel         id
# 2        uri  http://www.w3.org/2004/02/skos/core#altLabel         sv
# 3        uri  http://www.w3.org/2004/02/skos/core#altLabel         en
# 4        uri  http://www.w3.org/2004/02/skos/core#altLabel        ast
# ...      ...                                           ...        ...
# 34314    uri              http://www.wikidata.org/prop/P18        NaN
# 34315    uri              http://www.wikidata.org/prop/P19        NaN
# 34316    uri              http://www.wikidata.org/prop/P20        NaN
# 34317    uri              http://www.wikidata.org/prop/P21        NaN
# 34318    uri              http://www.wikidata.org/prop/P27        NaN
#
#         q.type                                            q.value  \
# 0      literal                                      Elisèu Reclus
# 1      literal                              Jacques Élisée Reclus
# 2      literal                         Jean Jacques Élisée Reclus
# 3      literal                              Jacques Élisée Reclus
# 4      literal                              Jacques Élisée Reclus
# ...        ...                                                ...
# 34314      uri  http://www.wikidata.org/entity/statement/Q3035...
# 34315      uri  http://www.wikidata.org/entity/statement/q3035...
# 34316      uri  http://www.wikidata.org/entity/statement/Q3035...
# 34317      uri  http://www.wikidata.org/entity/statement/Q3035...
# 34318      uri  http://www.wikidata.org/entity/statement/Q3035...
#
#       communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 0                                        fr                           literal
# 1                                        fr                           literal
# 2                                        fr                           literal
# 3                                        fr                           literal
# 4                                        fr                           literal
# ...                                     ...                               ...
# 34314                                    fr                           literal
# 34315                                    fr                           literal
# 34316                                    fr                           literal
# 34317                                    fr                           literal
# 34318                                    fr                           literal
#
#       communard_ou_communardeLabel.value pLabel.type  \
# 0                          Élisée Reclus     literal
# 1                          Élisée Reclus     literal
# 2                          Élisée Reclus     literal
# 3                          Élisée Reclus     literal
# 4                          Élisée Reclus     literal
# ...                                  ...         ...
# 34314                   Dominique Régère     literal
# 34315                   Dominique Régère     literal
# 34316                   Dominique Régère     literal
# 34317                   Dominique Régère     literal
# 34318                   Dominique Régère     literal
#
#                                        pLabel.value qLabel.type  \
# 0      http://www.w3.org/2004/02/skos/core#altLabel     literal
# 1      http://www.w3.org/2004/02/skos/core#altLabel     literal
# 2      http://www.w3.org/2004/02/skos/core#altLabel     literal
# 3      http://www.w3.org/2004/02/skos/core#altLabel     literal
# 4      http://www.w3.org/2004/02/skos/core#altLabel     literal
# ...                                             ...         ...
# 34314              http://www.wikidata.org/prop/P18     literal
# 34315              http://www.wikidata.org/prop/P19     literal
# 34316              http://www.wikidata.org/prop/P20     literal
# 34317              http://www.wikidata.org/prop/P21     literal
# 34318              http://www.wikidata.org/prop/P27     literal
#
#                                             qLabel.value q.datatype  \
# 0                                          Elisèu Reclus        NaN
# 1                                  Jacques Élisée Reclus        NaN
# 2                             Jean Jacques Élisée Reclus        NaN
# 3                                  Jacques Élisée Reclus        NaN
# 4                                  Jacques Élisée Reclus        NaN
# ...                                                  ...        ...
# 34314  statement/Q3035446-B6A89595-3458-4BB4-A585-269...        NaN
# 34315  statement/q3035446-26BEF6FE-AC9A-4BBC-A4C7-F0C...        NaN
# 34316  statement/Q3035446-A1D1C4ED-3E9B-4B9E-919C-977...        NaN
# 34317  statement/Q3035446-E073AA93-5474-4D10-9AF9-0D0...        NaN
# 34318  statement/Q3035446-127C76E0-2C09-4937-9A88-1C1...        NaN
#
#       qLabel.xml:lang
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 34314             NaN
# 34315             NaN
# 34316             NaN
# 34317             NaN
# 34318             NaN
#
# [34319 rows x 16 columns]

# %% [markdown]
# #### Quelques apperçu de travail sur ce df

# %%
#df_communard_tous_p_q.describe()

# %%
df_communard_tous_p_q.columns
# Out:
# Index(['communard_ou_communarde.type', 'communard_ou_communarde.value',
#        'p.type', 'p.value', 'q.xml:lang', 'q.type', 'q.value',
#        'communard_ou_communardeLabel.xml:lang',
#        'communard_ou_communardeLabel.type',
#        'communard_ou_communardeLabel.value', 'pLabel.type', 'pLabel.value',
#        'qLabel.type', 'qLabel.value', 'q.datatype', 'qLabel.xml:lang'],
#       dtype='object')

# %%
df_communard_tous_p_q.tail(25)
# Out:
#       communard_ou_communarde.type            communard_ou_communarde.value  \
# 34294                          uri  http://www.wikidata.org/entity/Q3035446
# 34295                          uri  http://www.wikidata.org/entity/Q3035446
# 34296                          uri  http://www.wikidata.org/entity/Q3035446
# 34297                          uri  http://www.wikidata.org/entity/Q3035446
# 34298                          uri  http://www.wikidata.org/entity/Q3035446
# 34299                          uri  http://www.wikidata.org/entity/Q3035446
# 34300                          uri  http://www.wikidata.org/entity/Q3035446
# 34301                          uri  http://www.wikidata.org/entity/Q3035446
# 34302                          uri  http://www.wikidata.org/entity/Q3035446
# 34303                          uri  http://www.wikidata.org/entity/Q3035446
# 34304                          uri  http://www.wikidata.org/entity/Q3035446
# 34305                          uri  http://www.wikidata.org/entity/Q3035446
# 34306                          uri  http://www.wikidata.org/entity/Q3035446
# 34307                          uri  http://www.wikidata.org/entity/Q3035446
# 34308                          uri  http://www.wikidata.org/entity/Q3035446
# 34309                          uri  http://www.wikidata.org/entity/Q3035446
# 34310                          uri  http://www.wikidata.org/entity/Q3035446
# 34311                          uri  http://www.wikidata.org/entity/Q3035446
# 34312                          uri  http://www.wikidata.org/entity/Q3035446
# 34313                          uri  http://www.wikidata.org/entity/Q3035446
# 34314                          uri  http://www.wikidata.org/entity/Q3035446
# 34315                          uri  http://www.wikidata.org/entity/Q3035446
# 34316                          uri  http://www.wikidata.org/entity/Q3035446
# 34317                          uri  http://www.wikidata.org/entity/Q3035446
# 34318                          uri  http://www.wikidata.org/entity/Q3035446
#
#       p.type                                            p.value q.xml:lang  \
# 34294    uri       http://www.w3.org/2004/02/skos/core#altLabel         en
# 34295    uri       http://www.w3.org/2004/02/skos/core#altLabel         fr
# 34296    uri       http://www.w3.org/2004/02/skos/core#altLabel         nl
# 34297    uri               http://wikiba.se/ontology#statements        NaN
# 34298    uri                http://wikiba.se/ontology#sitelinks        NaN
# 34299    uri              http://wikiba.se/ontology#identifiers        NaN
# 34300    uri            http://www.wikidata.org/prop/direct/P18        NaN
# 34301    uri            http://www.wikidata.org/prop/direct/P19        NaN
# 34302    uri            http://www.wikidata.org/prop/direct/P20        NaN
# 34303    uri            http://www.wikidata.org/prop/direct/P21        NaN
# 34304    uri            http://www.wikidata.org/prop/direct/P27        NaN
# 34305    uri            http://www.wikidata.org/prop/direct/P31        NaN
# 34306    uri           http://www.wikidata.org/prop/direct/P106        NaN
# 34307    uri           http://www.wikidata.org/prop/direct/P106        NaN
# 34308    uri           http://www.wikidata.org/prop/direct/P213        NaN
# 34309    uri           http://www.wikidata.org/prop/direct/P214        NaN
# 34310    uri           http://www.wikidata.org/prop/direct/P227        NaN
# 34311    uri           http://www.wikidata.org/prop/direct/P241        NaN
# 34312    uri  http://www.wikidata.org/prop/direct-normalized...        NaN
# 34313    uri  http://www.wikidata.org/prop/direct-normalized...        NaN
# 34314    uri                   http://www.wikidata.org/prop/P18        NaN
# 34315    uri                   http://www.wikidata.org/prop/P19        NaN
# 34316    uri                   http://www.wikidata.org/prop/P20        NaN
# 34317    uri                   http://www.wikidata.org/prop/P21        NaN
# 34318    uri                   http://www.wikidata.org/prop/P27        NaN
#
#         q.type                                            q.value  \
# 34294  literal                                   Dominique Regere
# 34295  literal                         Dominique Théophile Régère
# 34296  literal                                   Dominique Regere
# 34297  literal                                                 32
# 34298  literal                                                  3
# 34299  literal                                                  9
# 34300      uri  http://commons.wikimedia.org/wiki/Special:File...
# 34301      uri               http://www.wikidata.org/entity/Q1479
# 34302      uri             http://www.wikidata.org/entity/Q163948
# 34303      uri            http://www.wikidata.org/entity/Q6581097
# 34304      uri                http://www.wikidata.org/entity/Q142
# 34305      uri                  http://www.wikidata.org/entity/Q5
# 34306      uri             http://www.wikidata.org/entity/Q202883
# 34307      uri            http://www.wikidata.org/entity/Q1780490
# 34308  literal                                   0000000079515736
# 34309  literal                                          120980736
# 34310  literal                                          141394722
# 34311      uri            http://www.wikidata.org/entity/Q3095402
# 34312      uri                     http://viaf.org/viaf/120980736
# 34313      uri                    https://d-nb.info/gnd/141394722
# 34314      uri  http://www.wikidata.org/entity/statement/Q3035...
# 34315      uri  http://www.wikidata.org/entity/statement/q3035...
# 34316      uri  http://www.wikidata.org/entity/statement/Q3035...
# 34317      uri  http://www.wikidata.org/entity/statement/Q3035...
# 34318      uri  http://www.wikidata.org/entity/statement/Q3035...
#
#       communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 34294                                    fr                           literal
# 34295                                    fr                           literal
# 34296                                    fr                           literal
# 34297                                    fr                           literal
# 34298                                    fr                           literal
# 34299                                    fr                           literal
# 34300                                    fr                           literal
# 34301                                    fr                           literal
# 34302                                    fr                           literal
# 34303                                    fr                           literal
# 34304                                    fr                           literal
# 34305                                    fr                           literal
# 34306                                    fr                           literal
# 34307                                    fr                           literal
# 34308                                    fr                           literal
# 34309                                    fr                           literal
# 34310                                    fr                           literal
# 34311                                    fr                           literal
# 34312                                    fr                           literal
# 34313                                    fr                           literal
# 34314                                    fr                           literal
# 34315                                    fr                           literal
# 34316                                    fr                           literal
# 34317                                    fr                           literal
# 34318                                    fr                           literal
#
#       communard_ou_communardeLabel.value pLabel.type  \
# 34294                   Dominique Régère     literal
# 34295                   Dominique Régère     literal
# 34296                   Dominique Régère     literal
# 34297                   Dominique Régère     literal
# 34298                   Dominique Régère     literal
# 34299                   Dominique Régère     literal
# 34300                   Dominique Régère     literal
# 34301                   Dominique Régère     literal
# 34302                   Dominique Régère     literal
# 34303                   Dominique Régère     literal
# 34304                   Dominique Régère     literal
# 34305                   Dominique Régère     literal
# 34306                   Dominique Régère     literal
# 34307                   Dominique Régère     literal
# 34308                   Dominique Régère     literal
# 34309                   Dominique Régère     literal
# 34310                   Dominique Régère     literal
# 34311                   Dominique Régère     literal
# 34312                   Dominique Régère     literal
# 34313                   Dominique Régère     literal
# 34314                   Dominique Régère     literal
# 34315                   Dominique Régère     literal
# 34316                   Dominique Régère     literal
# 34317                   Dominique Régère     literal
# 34318                   Dominique Régère     literal
#
#                                             pLabel.value qLabel.type  \
# 34294       http://www.w3.org/2004/02/skos/core#altLabel     literal
# 34295       http://www.w3.org/2004/02/skos/core#altLabel     literal
# 34296       http://www.w3.org/2004/02/skos/core#altLabel     literal
# 34297               http://wikiba.se/ontology#statements     literal
# 34298                http://wikiba.se/ontology#sitelinks     literal
# 34299              http://wikiba.se/ontology#identifiers     literal
# 34300            http://www.wikidata.org/prop/direct/P18     literal
# 34301            http://www.wikidata.org/prop/direct/P19     literal
# 34302            http://www.wikidata.org/prop/direct/P20     literal
# 34303            http://www.wikidata.org/prop/direct/P21     literal
# 34304            http://www.wikidata.org/prop/direct/P27     literal
# 34305            http://www.wikidata.org/prop/direct/P31     literal
# 34306           http://www.wikidata.org/prop/direct/P106     literal
# 34307           http://www.wikidata.org/prop/direct/P106     literal
# 34308           http://www.wikidata.org/prop/direct/P213     literal
# 34309           http://www.wikidata.org/prop/direct/P214     literal
# 34310           http://www.wikidata.org/prop/direct/P227     literal
# 34311           http://www.wikidata.org/prop/direct/P241     literal
# 34312  http://www.wikidata.org/prop/direct-normalized...     literal
# 34313  http://www.wikidata.org/prop/direct-normalized...     literal
# 34314                   http://www.wikidata.org/prop/P18     literal
# 34315                   http://www.wikidata.org/prop/P19     literal
# 34316                   http://www.wikidata.org/prop/P20     literal
# 34317                   http://www.wikidata.org/prop/P21     literal
# 34318                   http://www.wikidata.org/prop/P27     literal
#
#                                             qLabel.value  \
# 34294                                   Dominique Regere
# 34295                         Dominique Théophile Régère
# 34296                                   Dominique Regere
# 34297                                                 32
# 34298                                                  3
# 34299                                                  9
# 34300  http://commons.wikimedia.org/wiki/Special:File...
# 34301                                           Bordeaux
# 34302                        10e arrondissement de Paris
# 34303                                           masculin
# 34304                                             France
# 34305                                        être humain
# 34306                                        vétérinaire
# 34307                            communard ou communarde
# 34308                                   0000000079515736
# 34309                                          120980736
# 34310                                          141394722
# 34311                                    Garde nationale
# 34312                     http://viaf.org/viaf/120980736
# 34313                    https://d-nb.info/gnd/141394722
# 34314  statement/Q3035446-B6A89595-3458-4BB4-A585-269...
# 34315  statement/q3035446-26BEF6FE-AC9A-4BBC-A4C7-F0C...
# 34316  statement/Q3035446-A1D1C4ED-3E9B-4B9E-919C-977...
# 34317  statement/Q3035446-E073AA93-5474-4D10-9AF9-0D0...
# 34318  statement/Q3035446-127C76E0-2C09-4937-9A88-1C1...
#
#                                      q.datatype qLabel.xml:lang
# 34294                                       NaN             NaN
# 34295                                       NaN             NaN
# 34296                                       NaN             NaN
# 34297  http://www.w3.org/2001/XMLSchema#integer             NaN
# 34298  http://www.w3.org/2001/XMLSchema#integer             NaN
# 34299  http://www.w3.org/2001/XMLSchema#integer             NaN
# 34300                                       NaN             NaN
# 34301                                       NaN              fr
# 34302                                       NaN              fr
# 34303                                       NaN              fr
# 34304                                       NaN              fr
# 34305                                       NaN              fr
# 34306                                       NaN              fr
# 34307                                       NaN              fr
# 34308                                       NaN             NaN
# 34309                                       NaN             NaN
# 34310                                       NaN             NaN
# 34311                                       NaN              fr
# 34312                                       NaN             NaN
# 34313                                       NaN             NaN
# 34314                                       NaN             NaN
# 34315                                       NaN             NaN
# 34316                                       NaN             NaN
# 34317                                       NaN             NaN
# 34318                                       NaN             NaN

# %% [markdown]
# #### Nettoyer le df et le mettre dans df_tout_sur_tous_communard

# %%
# retirer les colonnes "inutiles"
df_nettoyage_colonne = df_communard_tous_p_q.loc[:,['communard_ou_communarde.value','p.value','q.value','communard_ou_communardeLabel.xml:lang','communard_ou_communardeLabel.value', 'pLabel.value','qLabel.value', 'q.xml:lang']]
# garder le français
df_nettoyage_langue = df_nettoyage_colonne[df_nettoyage_colonne['q.xml:lang'] == ("fr" or "NaN")]

# %%
df_nettoyage_langue.describe()
# Out:
#                  communard_ou_communarde.value  \
# count                                     1072
# unique                                     309
# top     http://www.wikidata.org/entity/Q309722
# freq                                        11
#
#                                            p.value     q.value  \
# count                                         1072        1072
# unique                                          10         774
# top     http://www.w3.org/2000/01/rdf-schema#label  communarde
# freq                                           309          47
#
#        communard_ou_communardeLabel.xml:lang  \
# count                                   1072
# unique                                     1
# top                                       fr
# freq                                    1072
#
#        communard_ou_communardeLabel.value  \
# count                                1072
# unique                                309
# top                       Auguste Blanqui
# freq                                   11
#
#                                       pLabel.value qLabel.value q.xml:lang
# count                                         1072         1072       1072
# unique                                          10          774          1
# top     http://www.w3.org/2000/01/rdf-schema#label   communarde         fr
# freq                                           309           47       1072

# %%
# Avoir un df exploitable pour la suite
df_tout_sur_tous_communard = df_nettoyage_langue
