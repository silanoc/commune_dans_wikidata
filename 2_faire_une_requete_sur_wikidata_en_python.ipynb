# %% [markdown]
# # La Commune de Paris 1871 en liberté - Faire une requête sur wikidata en Python

# %% [markdown]
# Ce chapitre documente un point technique important pour la suite. Il explique comment le code fonctionne, et n'interroge pas la pertinance des choix de la requête. Cela est vu à d'autres moment.
#
# L'exemple est pris sur la recherche des communard·e·s présent·e·s dans Wikidata. L'explication de qu'est ce qu'un·e "communard·e·s présent·e·s dans Wikidata" sera vu plus loin.
#
# ### Méthode
#
# La classe Extraction_wikidata, est une adaption du modèle de réquête en python qui se trouve sur https://query.wikidata.org/
#
# - dans la variable query, il faut copier/coller la requête faite dans query.wikidata.org
# - exécuter les cellules "## 0" à "## 5" comme si dessous afin d'obtenir le résultat dans un dataframe exploitable pour faire des manipulations de données.
#
# Cela est reproductible, et l'est à de nombreuses occurence dans le document, sur plusieurs requêtes.
# Il suffit de changer la valeur de query (en ## 1) puis personnaliser les ##4 et 5 pour obtenir un tableau (dataframe) exploitable.

# %%
# les installations nécessaires
#https://rdflib.github.io/sparqlwrapper/
#!pip install sparqlwrapper
#!pip install seaborn

# %%
## 0 - import
import sys

from SPARQLWrapper import SPARQLWrapper, JSON

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import HTML

# %%
## 1 - les variables
endpoint_url:str = "https://query.wikidata.org/sparql"

# %%
query:str = """SELECT ?communard_ou_communarde ?communard_ou_communardeLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],fr". }
  # ?communard_ou_communarde wdt:P106 wd:Q1780490.
}"""

# %%
## 2 - l'objet
class Extraction_wikidata():
    def __init__(self, endpoint_url:str, query:str):
        self.endpoint_url:str = endpoint_url
        self.query:str = query
        
    def get_results(self, endpoint_url:str, query:str):
        user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
        # TODO adjust user agent; see https://w.wiki/CX6
        sparql = SPARQLWrapper(endpoint_url, agent = user_agent)
        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)
        return sparql.query().convert()
    
    def json_to_df(self, entree):
        #results = sparql.query().convert()
        df_results = pd.json_normalize(entree["results"]["bindings"])
        return df_results
    
    def extraire_et_df(self):
        extract_json = self.get_results(self.endpoint_url, self.query)
        extract_df = self.json_to_df(extract_json)
        return extract_df

# %%
## 3 - instantiation de l'objet et récupération du df
extraction_communard = Extraction_wikidata(endpoint_url, query)
df_communard = extraction_communard.extraire_et_df()

# %%
## 4 - afficher le df voulu
print(df_communard)
# Out:
#     communard_ou_communarde.type              communard_ou_communarde.value  \
# 0                            uri      http://www.wikidata.org/entity/Q20951
# 1                            uri      http://www.wikidata.org/entity/Q34618
# 2                            uri     http://www.wikidata.org/entity/Q184535
# 3                            uri     http://www.wikidata.org/entity/Q216092
# 4                            uri     http://www.wikidata.org/entity/Q257950
# ..                           ...                                        ...
# 304                          uri  http://www.wikidata.org/entity/Q115257385
# 305                          uri  http://www.wikidata.org/entity/Q115257386
# 306                          uri  http://www.wikidata.org/entity/Q115257387
# 307                          uri  http://www.wikidata.org/entity/Q115257388
# 308                          uri  http://www.wikidata.org/entity/Q118198782
#
#     communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 0                                      fr                           literal
# 1                                      fr                           literal
# 2                                      fr                           literal
# 3                                      fr                           literal
# 4                                      fr                           literal
# ..                                    ...                               ...
# 304                                    fr                           literal
# 305                                    fr                           literal
# 306                                    fr                           literal
# 307                                    fr                           literal
# 308                                    fr                           literal
#
#     communard_ou_communardeLabel.value
# 0                        Élisée Reclus
# 1                      Gustave Courbet
# 2                   Sofia Kovalevskaïa
# 3                        Louise Michel
# 4          Auguste-Jean-Marie Vermorel
# ..                                 ...
# 304                       Sophie Graix
# 305                    Joséphine Pratt
# 306                Céline Delvainquier
# 307                 Aimée Delvainquier
# 308                     Michel Sérigné
#
# [309 rows x 5 columns]

# %%
## 5 - quelques statistiques sur le df
#df_communard.describe()

# %%
df_communard_en_html = df_communard.to_html(columns = ['communard_ou_communarde.value', 'communard_ou_communardeLabel.value'])
HTML(df_communard_en_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>communard_ou_communarde.value</th>
#       <th>communard_ou_communardeLabel.value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://www.wikidata.org/entity/Q20951</td>
#       <td>Élisée Reclus</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://www.wikidata.org/entity/Q34618</td>
#       <td>Gustave Courbet</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://www.wikidata.org/entity/Q184535</td>
#       <td>Sofia Kovalevskaïa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://www.wikidata.org/entity/Q216092</td>
#       <td>Louise Michel</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://www.wikidata.org/entity/Q257950</td>
#       <td>Auguste-Jean-Marie Vermorel</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://www.wikidata.org/entity/Q274464</td>
#       <td>Édouard Vaillant</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>http://www.wikidata.org/entity/Q309722</td>
#       <td>Auguste Blanqui</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>http://www.wikidata.org/entity/Q312915</td>
#       <td>Eugène Pottier</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://www.wikidata.org/entity/Q337628</td>
#       <td>Piotr Lavrov</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>http://www.wikidata.org/entity/Q349485</td>
#       <td>Jules Allix</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>http://www.wikidata.org/entity/Q386390</td>
#       <td>Olivier Souêtre</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>http://www.wikidata.org/entity/Q441121</td>
#       <td>Jean-Louis Pindy</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>http://www.wikidata.org/entity/Q454246</td>
#       <td>Nina de Callias</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>http://www.wikidata.org/entity/Q458559</td>
#       <td>André Léo</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>http://www.wikidata.org/entity/Q465213</td>
#       <td>Jarosław Dombrowski</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>http://www.wikidata.org/entity/Q515589</td>
#       <td>Jean Baptiste Clément</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>http://www.wikidata.org/entity/Q517027</td>
#       <td>Gustave Flourens</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>http://www.wikidata.org/entity/Q518827</td>
#       <td>André Gill</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>http://www.wikidata.org/entity/Q520977</td>
#       <td>Charles Beslay</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>http://www.wikidata.org/entity/Q539458</td>
#       <td>Jean Allemane</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>http://www.wikidata.org/entity/Q551597</td>
#       <td>Jules Vallès</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>http://www.wikidata.org/entity/Q551648</td>
#       <td>Jules Dalou</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>http://www.wikidata.org/entity/Q598272</td>
#       <td>Jules Andrieu</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>http://www.wikidata.org/entity/Q621029</td>
#       <td>Charles Delescluze</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>http://www.wikidata.org/entity/Q642060</td>
#       <td>Henri Rochefort</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>http://www.wikidata.org/entity/Q656691</td>
#       <td>Émile Eudes</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>http://www.wikidata.org/entity/Q684449</td>
#       <td>Gustave Paul Cluseret</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>http://www.wikidata.org/entity/Q700018</td>
#       <td>Léo Frankel</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>http://www.wikidata.org/entity/Q726985</td>
#       <td>Walery Wroblewski</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>http://www.wikidata.org/entity/Q744276</td>
#       <td>Jacques Louis Durand</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>http://www.wikidata.org/entity/Q744469</td>
#       <td>Eugène Vermersch</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>http://www.wikidata.org/entity/Q950710</td>
#       <td>Henri Chouteau</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>http://www.wikidata.org/entity/Q955905</td>
#       <td>Auguste Serraillier</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>http://www.wikidata.org/entity/Q1065362</td>
#       <td>Charles Longuet</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>http://www.wikidata.org/entity/Q1117646</td>
#       <td>Charles Lullier</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>http://www.wikidata.org/entity/Q1118848</td>
#       <td>Paschal Grousset</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>http://www.wikidata.org/entity/Q1122778</td>
#       <td>Émile Léopold Clément</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>http://www.wikidata.org/entity/Q1125847</td>
#       <td>Henry Bauër</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>http://www.wikidata.org/entity/Q1959369</td>
#       <td>François Jourde</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>http://www.wikidata.org/entity/Q2008597</td>
#       <td>Anna Jaclard</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>http://www.wikidata.org/entity/Q2015151</td>
#       <td>Benoît Malon</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>http://www.wikidata.org/entity/Q2020304</td>
#       <td>Jules-Paul Johannard</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>http://www.wikidata.org/entity/Q2021981</td>
#       <td>Arthur Ranc</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>http://www.wikidata.org/entity/Q2287435</td>
#       <td>Simon Deutsch</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>http://www.wikidata.org/entity/Q2332848</td>
#       <td>Raoul Rigault</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>http://www.wikidata.org/entity/Q2376768</td>
#       <td>Armand Antoine Jules Arnaud</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>http://www.wikidata.org/entity/Q2383390</td>
#       <td>Gustave Maroteau</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>http://www.wikidata.org/entity/Q2426660</td>
#       <td>Eugène Varlin</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>http://www.wikidata.org/entity/Q2476089</td>
#       <td>Napoléon La Cécilia</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>http://www.wikidata.org/entity/Q2477042</td>
#       <td>Gustave Lefrançais</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>http://www.wikidata.org/entity/Q2512019</td>
#       <td>Père Tanguy</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>http://www.wikidata.org/entity/Q2643165</td>
#       <td>Arthur Arnould</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>http://www.wikidata.org/entity/Q2706181</td>
#       <td>Nathalie Lemel</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>http://www.wikidata.org/entity/Q2707971</td>
#       <td>Élisabeth Dmitrieff</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>http://www.wikidata.org/entity/Q2711077</td>
#       <td>Pierre Vésinier</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>http://www.wikidata.org/entity/Q2754922</td>
#       <td>Amilcare Cipriani</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>http://www.wikidata.org/entity/Q2823036</td>
#       <td>Achille Ballière</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>http://www.wikidata.org/entity/Q2824709</td>
#       <td>Adolf Rozwadowski</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>http://www.wikidata.org/entity/Q2824769</td>
#       <td>Adolphe Assi</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>http://www.wikidata.org/entity/Q2824796</td>
#       <td>Adolphe Clémence</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>http://www.wikidata.org/entity/Q2825426</td>
#       <td>Adèle Esquiros</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>http://www.wikidata.org/entity/Q2826417</td>
#       <td>Agar</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>http://www.wikidata.org/entity/Q2831493</td>
#       <td>Albert Regnard</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>http://www.wikidata.org/entit

# %% [markdown]
# ### Avoir TOUTES les informations sur les communard·e·s

# %% [markdown]
# Cette requête, qui fonctionne comme expliqué ci dessus est importante. Car en plus de charger toutes les personnes concernées (leur label) elle récupére toutes les données liées à leur élément.
#
# Ce dataframe sera ré-utilisé à de nombreuses occasions.
#
# Pour toutes les personnes, chercher les ?p ?q avec gestion des labels.
# Attention : c'est lourd !

# %% [markdown]
# #### Aller chercher les valeurs et les mettre dans un dataframe (df) nommé df_communard_tous_p_q

# %%
query = """SELECT ?communard_ou_communarde ?communard_ou_communardeLabel ?p ?pLabel ?q ?qLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "fr,en".
                         # ?communard_ou_communarde rdfs:label ?communard_ou_communardeLabel.
                         # ?p rdfs:label ?pLabel.
                         # ?q rdfs:label ?qLabel.}
  
  # ?communard_ou_communarde wdt:P106 wd:Q1780490;
                           # ?p ?q. 
}
"""

# %%
extraction_communard_tous_p_q = Extraction_wikidata(endpoint_url, query)
df_communard_tous_p_q = extraction_communard_tous_p_q.extraire_et_df()

# %%
df_communard_tous_p_q
# Out:
#       communard_ou_communarde.type            communard_ou_communarde.value  \
# 0                              uri    http://www.wikidata.org/entity/Q20951
# 1                              uri    http://www.wikidata.org/entity/Q20951
# 2                              uri    http://www.wikidata.org/entity/Q20951
# 3                              uri    http://www.wikidata.org/entity/Q20951
# 4                              uri    http://www.wikidata.org/entity/Q20951
# ...                            ...                                      ...
# 34332                          uri  http://www.wikidata.org/entity/Q3083515
# 34333                          uri  http://www.wikidata.org/entity/Q3083515
# 34334                          uri  http://www.wikidata.org/entity/Q3083515
# 34335                          uri  http://www.wikidata.org/entity/Q3083515
# 34336                          uri  http://www.wikidata.org/entity/Q3083515
#
#       p.type                             p.value  \
# 0        uri           http://schema.org/version
# 1        uri      http://schema.org/dateModified
# 2        uri       http://schema.org/description
# 3        uri       http://schema.org/description
# 4        uri       http://schema.org/description
# ...      ...                                 ...
# 34332    uri  http://www.wikidata.org/prop/P1412
# 34333    uri  http://www.wikidata.org/prop/P1559
# 34334    uri  http://www.wikidata.org/prop/P1596
# 34335    uri  http://www.wikidata.org/prop/P2671
# 34336    uri  http://www.wikidata.org/prop/P4724
#
#                                       q.datatype   q.type  \
# 0       http://www.w3.org/2001/XMLSchema#integer  literal
# 1      http://www.w3.org/2001/XMLSchema#dateTime  literal
# 2                                            NaN  literal
# 3                                            NaN  literal
# 4                                            NaN  literal
# ...                                          ...      ...
# 34332                                        NaN      uri
# 34333                                        NaN      uri
# 34334                                        NaN      uri
# 34335                                        NaN      uri
# 34336                                        NaN      uri
#
#                                                  q.value  \
# 0                                             2256724589
# 1                                   2024-10-05T17:42:23Z
# 2                                         ލިޔުންތެރިއެއް
# 3                             France karimba ŋun nyɛ doo
# 4                       francouzský geograf a anarchista
# ...                                                  ...
# 34332  http://www.wikidata.org/entity/statement/Q3083...
# 34333  http://www.wikidata.org/entity/statement/Q3083...
# 34334  http://www.wikidata.org/entity/statement/Q3083...
# 34335  http://www.wikidata.org/entity/statement/Q3083...
# 34336  http://www.wikidata.org/entity/statement/Q3083...
#
#       communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 0                                        fr                           literal
# 1                                        fr                           literal
# 2                                        fr                           literal
# 3                                        fr                           literal
# 4                                        fr                           literal
# ...                                     ...                               ...
# 34332                                    fr                           literal
# 34333                                    fr                           literal
# 34334                                    fr                           literal
# 34335                                    fr                           literal
# 34336                                    fr                           literal
#
#       communard_ou_communardeLabel.value pLabel.type  \
# 0                          Élisée Reclus     literal
# 1                          Élisée Reclus     literal
# 2                          Élisée Reclus     literal
# 3                          Élisée Reclus     literal
# 4                          Élisée Reclus     literal
# ...                                  ...         ...
# 34332             François-Louis Parisel     literal
# 34333             François-Louis Parisel     literal
# 34334             François-Louis Parisel     literal
# 34335             François-Louis Parisel     literal
# 34336             François-Louis Parisel     literal
#
#                              pLabel.value qLabel.type  \
# 0               http://schema.org/version     literal
# 1          http://schema.org/dateModified     literal
# 2           http://schema.org/description     literal
# 3           http://schema.org/description     literal
# 4           http://schema.org/description     literal
# ...                                   ...         ...
# 34332  http://www.wikidata.org/prop/P1412     literal
# 34333  http://www.wikidata.org/prop/P1559     literal
# 34334  http://www.wikidata.org/prop/P1596     literal
# 34335  http://www.wikidata.org/prop/P2671     literal
# 34336  http://www.wikidata.org/prop/P4724     literal
#
#                                             qLabel.value q.xml:lang  \
# 0                                             2256724589        NaN
# 1                                   2024-10-05T17:42:23Z        NaN
# 2                                         ލިޔުންތެރިއެއް         dv
# 3                             France karimba ŋun nyɛ doo        dag
# 4                       francouzský geograf a anarchista         cs
# ...                                                  ...        ...
# 34332  statement/Q3083515-5A31CF4A-B593-496C-A271-CEA...        NaN
# 34333  statement/Q3083515-6F000457-A1A2-45B7-9209-873...        NaN
# 34334  statement/Q3083515-34979a69-4553-0922-956c-0f4...        NaN
# 34335  statement/Q3083515-D5DCA60C-88FE-4EC8-8F6D-EDE...        NaN
# 34336  statement/Q3083515-90313a08-44ad-31ee-9131-1a5...        NaN
#
#       qLabel.xml:lang
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 34332             NaN
# 34333             NaN
# 34334             NaN
# 34335             NaN
# 34336             NaN
#
# [34337 rows x 16 columns]

# %% [markdown]
# #### Quelques apperçu de travail sur ce df

# %%
#df_communard_tous_p_q.describe()

# %%
df_communard_tous_p_q.columns
# Out:
# Index(['communard_ou_communarde.type', 'communard_ou_communarde.value',
#        'p.type', 'p.value', 'q.xml:lang', 'q.type', 'q.value',
#        'communard_ou_communardeLabel.xml:lang',
#        'communard_ou_communardeLabel.type',
#        'communard_ou_communardeLabel.value', 'pLabel.type', 'pLabel.value',
#        'qLabel.type', 'qLabel.value', 'q.datatype', 'qLabel.xml:lang'],
#       dtype='object')

# %%
df_communard_tous_p_q.tail(50)
# Out:
#       communard_ou_communarde.type            communard_ou_communarde.value  \
# 34287                          uri  http://www.wikidata.org/entity/Q3083515
# 34288                          uri  http://www.wikidata.org/entity/Q3083515
# 34289                          uri  http://www.wikidata.org/entity/Q3083515
# 34290                          uri  http://www.wikidata.org/entity/Q3083515
# 34291                          uri  http://www.wikidata.org/entity/Q3083515
# 34292                          uri  http://www.wikidata.org/entity/Q3083515
# 34293                          uri  http://www.wikidata.org/entity/Q3083515
# 34294                          uri  http://www.wikidata.org/entity/Q3083515
# 34295                          uri  http://www.wikidata.org/entity/Q3083515
# 34296                          uri  http://www.wikidata.org/entity/Q3083515
# 34297                          uri  http://www.wikidata.org/entity/Q3083515
# 34298                          uri  http://www.wikidata.org/entity/Q3083515
# 34299                          uri  http://www.wikidata.org/entity/Q3083515
# 34300                          uri  http://www.wikidata.org/entity/Q3083515
# 34301                          uri  http://www.wikidata.org/entity/Q3083515
# 34302                          uri  http://www.wikidata.org/entity/Q3083515
# 34303                          uri  http://www.wikidata.org/entity/Q3083515
# 34304                          uri  http://www.wikidata.org/entity/Q3083515
# 34305                          uri  http://www.wikidata.org/entity/Q3083515
# 34306                          uri  http://www.wikidata.org/entity/Q3083515
# 34307                          uri  http://www.wikidata.org/entity/Q3083515
# 34308                          uri  http://www.wikidata.org/entity/Q3083515
# 34309                          uri  http://www.wikidata.org/entity/Q3083515
# 34310                          uri  http://www.wikidata.org/entity/Q3083515
# 34311                          uri  http://www.wikidata.org/entity/Q3083515
# 34312                          uri  http://www.wikidata.org/entity/Q3083515
# 34313                          uri  http://www.wikidata.org/entity/Q3083515
# 34314                          uri  http://www.wikidata.org/entity/Q3083515
# 34315                          uri  http://www.wikidata.org/entity/Q3083515
# 34316                          uri  http://www.wikidata.org/entity/Q3083515
# 34317                          uri  http://www.wikidata.org/entity/Q3083515
# 34318                          uri  http://www.wikidata.org/entity/Q3083515
# 34319                          uri  http://www.wikidata.org/entity/Q3083515
# 34320                          uri  http://www.wikidata.org/entity/Q3083515
# 34321                          uri  http://www.wikidata.org/entity/Q3083515
# 34322                          uri  http://www.wikidata.org/entity/Q3083515
# 34323                          uri  http://www.wikidata.org/entity/Q3083515
# 34324                          uri  http://www.wikidata.org/entity/Q3083515
# 34325                          uri  http://www.wikidata.org/entity/Q3083515
# 34326                          uri  http://www.wikidata.org/entity/Q3083515
# 34327                          uri  http://www.wikidata.org/entity/Q3083515
# 34328                          uri  http://www.wikidata.org/entity/Q3083515
# 34329                          uri  http://www.wikidata.org/entity/Q3083515
# 34330                          uri  http://www.wikidata.org/entity/Q3083515
# 34331                          uri  http://www.wikidata.org/entity/Q3083515
# 34332                          uri  http://www.wikidata.org/entity/Q3083515
# 34333                          uri  http://www.wikidata.org/entity/Q3083515
# 34334                          uri  http://www.wikidata.org/entity/Q3083515
# 34335                          uri  http://www.wikidata.org/entity/Q3083515
# 34336                          uri  http://www.wikidata.org/entity/Q3083515
#
#       p.type                                            p.value  \
# 34287    uri            http://www.wikidata.org/prop/direct/P19
# 34288    uri            http://www.wikidata.org/prop/direct/P20
# 34289    uri            http://www.wikidata.org/prop/direct/P21
# 34290    uri            http://www.wikidata.org/prop/direct/P27
# 34291    uri            http://www.wikidata.org/prop/direct/P31
# 34292    uri            http://www.wikidata.org/prop/direct/P69
# 34293    uri           http://www.wikidata.org/prop/direct/P106
# 34294    uri           http://www.wikidata.org/prop/direct/P106
# 34295    uri           http://www.wikidata.org/prop/direct/P214
# 34296    uri  http://www.wikidata.org/prop/direct-normalized...
# 34297    uri                   http://www.wikidata.org/prop/P19
# 34298    uri                   http://www.wikidata.org/prop/P20
# 34299    uri                   http://www.wikidata.org/prop/P21
# 34300    uri                   http://www.wikidata.org/prop/P27
# 34301    uri                   http://www.wikidata.org/prop/P31
# 34302    uri                   http://www.wikidata.org/prop/P69
# 34303    uri                  http://www.wikidata.org/prop/P106
# 34304    uri                  http://www.wikidata.org/prop/P106
# 34305    uri                  http://www.wikidata.org/prop/P214
# 34306    uri           http://www.wikidata.org/prop/direct/P268
# 34307    uri           http://www.wikidata.org/prop/direct/P269
# 34308    uri           http://www.wikidata.org/prop/direct/P463
# 34309    uri           http://www.wikidata.org/prop/direct/P463
# 34310    uri           http://www.wikidata.org/prop/direct/P569
# 34311    uri           http://www.wikidata.org/prop/direct/P570
# 34312    uri           http://www.wikidata.org/prop/direct/P607
# 34313    uri           http://www.wikidata.org/prop/direct/P734
# 34314    uri           http://www.wikidata.org/prop/direct/P735
# 34315    uri          http://www.wikidata.org/prop/direct/P1412
# 34316    uri          http://www.wikidata.org/prop/direct/P1559
# 34317    uri          http://www.wikidata.org/prop/direct/P1596
# 34318    uri          http://www.wikidata.org/prop/direct/P2671
# 34319    uri          http://www.wikidata.org/prop/direct/P4724
# 34320    uri  http://www.wikidata.org/prop/direct-normalized...
# 34321    uri  http://www.wikidata.org/prop/direct-normalized...
# 34322    uri  http://www.wikidata.org/prop/direct-normalized...
# 34323    uri                  http://www.wikidata.org/prop/P268
# 34324    uri                  http://www.wikidata.org/prop/P269
# 34325    uri                  http://www.wikidata.org/prop/P463
# 34326    uri                  http://www.wikidata.org/prop/P463
# 34327    uri                  http://www.wikidata.org/prop/P569
# 34328    uri                  http://www.wikidata.org/prop/P570
# 34329    uri                  http://www.wikidata.org/prop/P607
# 34330    uri                  http://www.wikidata.org/prop/P734
# 34331    uri                  http://www.wikidata.org/prop/P735
# 34332    uri                 http://www.wikidata.org/prop/P1412
# 34333    uri                 http://www.wikidata.org/prop/P1559
# 34334    uri                 http://www.wikidata.org/prop/P1596
# 34335    uri                 http://www.wikidata.org/prop/P2671
# 34336    uri                 http://www.wikidata.org/prop/P4724
#
#                                       q.datatype   q.type  \
# 34287                                        NaN      uri
# 34288                                        NaN      uri
# 34289                                        NaN      uri
# 34290                                        NaN      uri
# 34291                                        NaN      uri
# 34292                                        NaN      uri
# 34293                                        NaN      uri
# 34294                                        NaN      uri
# 34295                                        NaN  literal
# 34296                                        NaN      uri
# 34297                                        NaN      uri
# 34298                                        NaN      uri
# 34299                                        NaN      uri
# 34300                                        NaN      uri
# 34301                                        NaN      uri
# 34302                                        NaN      uri
# 34303                                        NaN      uri
# 34304                                        NaN      uri
# 34305                                        NaN      uri
# 34306                                        NaN  literal
# 34307                                        NaN  literal
# 34308                                        NaN      uri
# 34309                                        NaN      uri
# 34310  http://www.w3.org/2001/XMLSchema#dateTime  literal
# 34311  http://www.w3.org/2001/XMLSchema#dateTime  literal
# 34312                                        NaN      uri
# 34313                                        NaN      uri
# 34314                                        NaN      uri
# 34315                                        NaN      uri
# 34316                                        NaN  literal
# 34317                                        NaN      uri
# 34318                                        NaN  literal
# 34319                                        NaN  literal
# 34320                                        NaN      uri
# 34321                                        NaN      uri
# 34322                                        NaN      uri
# 34323                                        NaN      uri
# 34324                                        NaN      uri
# 34325                                        NaN      uri
# 34326                                        NaN      uri
# 34327                                        NaN      uri
# 34328                                        NaN      uri
# 34329                                        NaN      uri
# 34330                                        NaN      uri
# 34331                                        NaN      uri
# 34332                                        NaN      uri
# 34333                                        NaN      uri
# 34334                                        NaN      uri
# 34335                                        NaN      uri
# 34336                                        NaN      uri
#
#                                                  q.value  \
# 34287            http://www.wikidata.org/entity/Q3209735
# 34288              http://www.wikidata.org/entity/Q25395
# 34289            http://www.wikidata.org/entity/Q6581097
# 34290                http://www.wikidata.org/entity/Q142
# 34291                  http://www.wikidata.org/entity/Q5
# 34292            http://www.wikidata.org/entity/Q3064295
# 34293              http://www.wikidata.org/entity/Q39631
# 34294            http://www.wikidata.org/entity/Q1780490
# 34295                              259146284394915331471
# 34296         http://viaf.org/viaf/259146284394915331471
# 34297  http://www.wikidata.org/entity/statement/Q3083...
# 34298  http://www.wikidata.org/entity/statement/Q3083...
# 34299  http://www.wikidata.org/entity/statement/Q3083...
# 34300  http://www.wikidata.org/entity/statement/Q3083...
# 34301  http://www.wikidata.org/entity/statement/Q3083...
# 34302  http://www.wikidata.org/entity/statement/Q3083...
# 34303  http://www.wikidata.org/entity/statement/Q3083...
# 34304  http://www.wikidata.org/entity/statement/Q3083...
# 34305  http://www.wikidata.org/entity/statement/Q3083...
# 34306                                          107830869
# 34307                                          192805584
# 34308            http://www.wikidata.org/entity/Q2408404
# 34309            http://www.wikidata.org/entity/Q2993765
# 34310                               1841-10-17T00:00:00Z
# 34311                               1877-07-05T00:00:00Z
# 34312             http://www.wikidata.org/entity/Q690489
# 34313           http://www.wikidata.org/entity/Q65111781
# 34314            http://www.wikidata.org/entity/Q1166840
# 34315                http://www.wikidata.org/entity/Q150
# 34316                             François-Louis Parisel
# 34317               http://www.wikidata.org/entity/Q8454
# 34318                                        /g/121lyszb
# 34319                                              67547
# 34320    http://data.bnf.fr/ark:/12148/cb107830869#about
# 34321                   http://www.idref.fr/192805584/id
# 34322                          http://g.co/kg/g/121lyszb
# 34323  http://www.wikidata.org/entity/statement/Q3083...
# 34324  http://www.wikidata.org/entity/statement/Q3083...
# 34325  http://www.wikidata.org/entity/statement/Q3083...
# 34326  http://www.wikidata.org/entity/statement/Q3083...
# 34327  http://www.wikidata.org/entity/statement/Q3083...
# 34328  http://www.wikidata.org/entity/statement/Q3083...
# 34329  http://www.wikidata.org/entity/statement/Q3083...
# 34330  http://www.wikidata.org/entity/statement/Q3083...
# 34331  http://www.wikidata.org/entity/statement/Q3083...
# 34332  http://www.wikidata.org/entity/statement/Q3083...
# 34333  http://www.wikidata.org/entity/statement/Q3083...
# 34334  http://www.wikidata.org/entity/statement/Q3083...
# 34335  http://www.wikidata.org/entity/statement/Q3083...
# 34336  http://www.wikidata.org/entity/statement/Q3083...
#
#       communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 34287                                    fr                           literal
# 34288                                    fr                           literal
# 34289                                    fr                           literal
# 34290                                    fr                           literal
# 34291                                    fr                           literal
# 34292                                    fr                           literal
# 34293                                    fr                           literal
# 34294                                    fr                           literal
# 34295                                    fr                           literal
# 34296                                    fr                           literal
# 34297                                    fr                           literal
# 34298                                    fr                           literal
# 34299                                    fr                           literal
# 34300                                    fr                           literal
# 34301                                    fr                           literal
# 34302                                    fr                           literal
# 34303                                    fr                           literal
# 34304                                    fr                           literal
# 34305                                    fr                           literal
# 34306                                    fr                           literal
# 34307                                    fr                           literal
# 34308                                    fr                           literal
# 34309                                    fr                           literal
# 34310                                    fr                           literal
# 34311                                    fr                           literal
# 34312                                    fr                           literal
# 34313                                    fr                           literal
# 34314                                    fr                           literal
# 34315                                    fr                           literal
# 34316                                    fr                           literal
# 34317                                    fr                           literal
# 34318                                    fr                           literal
# 34319                                    fr                           literal
# 34320                                    fr                           literal
# 34321                                    fr                           literal
# 34322                                    fr                           literal
# 34323                                    fr                           literal
# 34324                                    fr                           literal
# 34325                                    fr                           literal
# 34326                                    fr                           literal
# 34327                                    fr                           literal
# 34328                                    fr                           literal
# 34329                                    fr                           literal
# 34330                                    fr                           literal
# 34331                                    fr                           literal
# 34332                                    fr                           literal
# 34333                                    fr                           literal
# 34334                                    fr                           literal
# 34335                                    fr                           literal
# 34336                                    fr                           literal
#
#       communard_ou_communardeLabel.value pLabel.type  \
# 34287             François-Louis Parisel     literal
# 34288             François-Louis Parisel     literal
# 34289             François-Louis Parisel     literal
# 34290             François-Louis Parisel     literal
# 34291             François-Louis Parisel     literal
# 34292             François-Louis Parisel     literal
# 34293             François-Louis Parisel     literal
# 34294             François-Louis Parisel     literal
# 34295             François-Louis Parisel     literal
# 34296             François-Louis Parisel     literal
# 34297             François-Louis Parisel     literal
# 34298             François-Louis Parisel     literal
# 34299             François-Louis Parisel     literal
# 34300             François-Louis Parisel     literal
# 34301             François-Louis Parisel     literal
# 34302             François-Louis Parisel     literal
# 34303             François-Louis Parisel     literal
# 34304             François-Louis Parisel     literal
# 34305             François-Louis Parisel     literal
# 34306             François-Louis Parisel     literal
# 34307             François-Louis Parisel     literal
# 34308             François-Louis Parisel     literal
# 34309             François-Louis Parisel     literal
# 34310             François-Louis Parisel     literal
# 34311             François-Louis Parisel     literal
# 34312             François-Louis Parisel     literal
# 34313             François-Louis Parisel     literal
# 34314             François-Louis Parisel     literal
# 34315             François-Louis Parisel     literal
# 34316             François-Louis Parisel     literal
# 34317             François-Louis Parisel     literal
# 34318             François-Louis Parisel     literal
# 34319             François-Louis Parisel     literal
# 34320             François-Louis Parisel     literal
# 34321             François-Louis Parisel     literal
# 34322             François-Louis Parisel     literal
# 34323             François-Louis Parisel     literal
# 34324             François-Louis Parisel     literal
# 34325             François-Louis Parisel     literal
# 34326             François-Louis Parisel     literal
# 34327             François-Louis Parisel     literal
# 34328             François-Louis Parisel     literal
# 34329             François-Louis Parisel     literal
# 34330             François-Louis Parisel     literal
# 34331             François-Louis Parisel     literal
# 34332             François-Louis Parisel     literal
# 34333             François-Louis Parisel     literal
# 34334             François-Louis Parisel     literal
# 34335             François-Louis Parisel     literal
# 34336             François-Louis Parisel     literal
#
#                                             pLabel.value qLabel.type  \
# 34287            http://www.wikidata.org/prop/direct/P19     literal
# 34288            http://www.wikidata.org/prop/direct/P20     literal
# 34289            http://www.wikidata.org/prop/direct/P21     literal
# 34290            http://www.wikidata.org/prop/direct/P27     literal
# 34291            http://www.wikidata.org/prop/direct/P31     literal
# 34292            http://www.wikidata.org/prop/direct/P69     literal
# 34293           http://www.wikidata.org/prop/direct/P106     literal
# 34294           http://www.wikidata.org/prop/direct/P106     literal
# 34295           http://www.wikidata.org/prop/direct/P214     literal
# 34296  http://www.wikidata.org/prop/direct-normalized...     literal
# 34297                   http://www.wikidata.org/prop/P19     literal
# 34298                   http://www.wikidata.org/prop/P20     literal
# 34299                   http://www.wikidata.org/prop/P21     literal
# 34300                   http://www.wikidata.org/prop/P27     literal
# 34301                   http://www.wikidata.org/prop/P31     literal
# 34302                   http://www.wikidata.org/prop/P69     literal
# 34303                  http://www.wikidata.org/prop/P106     literal
# 34304                  http://www.wikidata.org/prop/P106     literal
# 34305                  http://www.wikidata.org/prop/P214     literal
# 34306           http://www.wikidata.org/prop/direct/P268     literal
# 34307           http://www.wikidata.org/prop/direct/P269     literal
# 34308           http://www.wikidata.org/prop/direct/P463     literal
# 34309           http://www.wikidata.org/prop/direct/P463     literal
# 34310           http://www.wikidata.org/prop/direct/P569     literal
# 34311           http://www.wikidata.org/prop/direct/P570     literal
# 34312           http://www.wikidata.org/prop/direct/P607     literal
# 34313           http://www.wikidata.org/prop/direct/P734     literal
# 34314           http://www.wikidata.org/prop/direct/P735     literal
# 34315          http://www.wikidata.org/prop/direct/P1412     literal
# 34316          http://www.wikidata.org/prop/direct/P1559     literal
# 34317          http://www.wikidata.org/prop/direct/P1596     literal
# 34318          http://www.wikidata.org/prop/direct/P2671     literal
# 34319          http://www.wikidata.org/prop/direct/P4724     literal
# 34320  http://www.wikidata.org/prop/direct-normalized...     literal
# 34321  http://www.wikidata.org/prop/direct-normalized...     literal
# 34322  http://www.wikidata.org/prop/direct-normalized...     literal
# 34323                  http://www.wikidata.org/prop/P268     literal
# 34324                  http://www.wikidata.org/prop/P269     literal
# 34325                  http://www.wikidata.org/prop/P463     literal
# 34326                  http://www.wikidata.org/prop/P463     literal
# 34327                  http://www.wikidata.org/prop/P569     literal
# 34328                  http://www.wikidata.org/prop/P570     literal
# 34329                  http://www.wikidata.org/prop/P607     literal
# 34330                  http://www.wikidata.org/prop/P734     literal
# 34331                  http://www.wikidata.org/prop/P735     literal
# 34332                 http://www.wikidata.org/prop/P1412     literal
# 34333                 http://www.wikidata.org/prop/P1559     literal
# 34334                 http://www.wikidata.org/prop/P1596     literal
# 34335                 http://www.wikidata.org/prop/P2671     literal
# 34336                 http://www.wikidata.org/prop/P4724     literal
#
#                                             qLabel.value q.xml:lang  \
# 34287                                     La Guillotière        NaN
# 34288                                             Newark        NaN
# 34289                                           masculin        NaN
# 34290                                             France        NaN
# 34291                                        être humain        NaN
# 34292                      faculté de pharmacie de Paris        NaN
# 34293                                            médecin        NaN
# 34294                            communard ou communarde        NaN
# 34295                              259146284394915331471        NaN
# 34296         http://viaf.org/viaf/259146284394915331471        NaN
# 34297  statement/Q3083515-7A48871B-4C5F-41F9-B904-418...        NaN
# 34298  statement/Q3083515-22FBE624-062F-4C1F-A514-12C...        NaN
# 34299  statement/Q3083515-5B620F16-9950-4156-A40D-CF0...        NaN
# 34300  statement/Q3083515-762677B4-EA09-4AFA-98B7-01E...        NaN
# 34301  statement/Q3083515-8B9AEA69-22CD-41D2-AB13-06C...        NaN
# 34302  statement/Q3083515-3BD1D430-57D6-401A-B991-86F...        NaN
# 34303  statement/Q3083515-6E75C7C9-33C2-4EF7-B089-915...        NaN
# 34304  statement/Q3083515-705AE074-F103-4964-BB16-23F...        NaN
# 34305  statement/Q3083515-753DCFBF-4C16-453D-8E5B-87D...        NaN
# 34306                                          107830869        NaN
# 34307                                          192805584        NaN
# 34308  Comité central républicain des Vingt arrondiss...        NaN
# 34309                              Conseil de la Commune        NaN
# 34310                               1841-10-17T00:00:00Z        NaN
# 34311                               1877-07-05T00:00:00Z        NaN
# 34312                                     siège de Paris        NaN
# 34313                                            Parisel        NaN
# 34314                                           François        NaN
# 34315                                           français        NaN
# 34316                             François-Louis Parisel         fr
# 34317                                      peine de mort        NaN
# 34318                                        /g/121lyszb        NaN
# 34319                                              67547        NaN
# 34320    http://data.bnf.fr/ark:/12148/cb107830869#about        NaN
# 34321                   http://www.idref.fr/192805584/id        NaN
# 34322                          http://g.co/kg/g/121lyszb        NaN
# 34323  statement/Q3083515-E6CE9EC9-D43C-4B33-B97B-9AF...        NaN
# 34324  statement/Q3083515-E770B155-712E-4D15-94A6-436...        NaN
# 34325  statement/Q3083515-41A97B9B-8C26-439E-9F01-7EB...        NaN
# 34326  statement/Q3083515-C4A3AB5B-3FD5-44F7-B458-ED0...        NaN
# 34327  statement/Q3083515-5731C1D8-8F49-4DA9-A8B2-92D...        NaN
# 34328  statement/Q3083515-7A6B25C6-EABF-4416-83E7-957...        NaN
# 34329  statement/Q3083515-243F2B4A-9280-4113-955F-54C...        NaN
# 34330  statement/Q3083515-CBFB781D-BE32-4C8E-B3A0-061...        NaN
# 34331  statement/Q3083515-37B89689-7FB6-43A0-A728-344...        NaN
# 34332  statement/Q3083515-5A31CF4A-B593-496C-A271-CEA...        NaN
# 34333  statement/Q3083515-6F000457-A1A2-45B7-9209-873...        NaN
# 34334  statement/Q3083515-34979a69-4553-0922-956c-0f4...        NaN
# 34335  statement/Q3083515-D5DCA60C-88FE-4EC8-8F6D-EDE...        NaN
# 34336  statement/Q3083515-90313a08-44ad-31ee-9131-1a5...        NaN
#
#       qLabel.xml:lang
# 34287              fr
# 34288              fr
# 34289              fr
# 34290              fr
# 34291              fr
# 34292              fr
# 34293              fr
# 34294              fr
# 34295             NaN
# 34296             NaN
# 34297             NaN
# 34298             NaN
# 34299             NaN
# 34300             NaN
# 34301             NaN
# 34302             NaN
# 34303             NaN
# 34304             NaN
# 34305             NaN
# 34306             NaN
# 34307             NaN
# 34308              fr
# 34309              fr
# 34310             NaN
# 34311             NaN
# 34312              fr
# 34313              fr
# 34314              fr
# 34315              fr
# 34316             NaN
# 34317              fr
# 34318             NaN
# 34319             NaN
# 34320             NaN
# 34321             NaN
# 34322             NaN
# 34323             NaN
# 34324             NaN
# 34325             NaN
# 34326             NaN
# 34327             NaN
# 34328             NaN
# 34329             NaN
# 34330             NaN
# 34331             NaN
# 34332             NaN
# 34333             NaN
# 34334             NaN
# 34335             NaN
# 34336             NaN

# %% [markdown]
# #### Nettoyer le df et le mettre dans df_tout_sur_tous_communard

# %%
# retirer les colonnes "inutiles"
df_nettoyage_colonne = df_communard_tous_p_q.loc[:,['communard_ou_communarde.value','p.value','q.value','communard_ou_communardeLabel.xml:lang','communard_ou_communardeLabel.value', 'pLabel.value','qLabel.value', 'q.xml:lang']]
# garder le français
df_nettoyage_langue = df_nettoyage_colonne[df_nettoyage_colonne['q.xml:lang'] == ("fr" or "NaN")]

# %%
df_nettoyage_langue.describe()
# Out:
#                  communard_ou_communarde.value  \
# count                                     1072
# unique                                     309
# top     http://www.wikidata.org/entity/Q309722
# freq                                        11
#
#                                            p.value     q.value  \
# count                                         1072        1072
# unique                                          10         774
# top     http://www.w3.org/2000/01/rdf-schema#label  communarde
# freq                                           309          47
#
#        communard_ou_communardeLabel.xml:lang  \
# count                                   1072
# unique                                     1
# top                                       fr
# freq                                    1072
#
#        communard_ou_communardeLabel.value  \
# count                                1072
# unique                                309
# top                       Auguste Blanqui
# freq                                   11
#
#                                       pLabel.value qLabel.value q.xml:lang
# count                                         1072         1072       1072
# unique                                          10          774          1
# top     http://www.w3.org/2000/01/rdf-schema#label   communarde         fr
# freq                                           309           47       1072

# %%
# Avoir un df exploitable pour la suite
df_tout_sur_tous_communard = df_nettoyage_langue

# %% [markdown]
# ## fichiers pythons
# Ces scripts sont ré-écrits dans les fichiers :
# - extraction_wd.py pour faire une requete dans wikidata et obtenir un dataframe à exploiter en Python.
# - extraction_communard1.py pour chercher les informations sur les communard, les mettres dans un dataframe et les analyser en Python

# %% [markdown]
# ## Licence
#
# Ce travail est sous licence libre plus précisement Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International.
#
# Il est fait à partir de données libres (diverse licence) et logiciels ou formats libres.
# Citons python, notebook, makedon, mediawiki...
# J'autorise la diffusion commerciale pour payer les frais de papier si quelqu'an veut le diffuser en version papier.
# Par principe, la licence vous autorise à utiliser ce travail sans m'en informer, juste pour ma curiosité, merci de me le signaler.
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Cette œuvre est mise à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
#
# La version originale du notebook et des fichiers liées sont versionnés et héberger sur github.
# https://github.com/silanoc/commune_dans_wikidata
