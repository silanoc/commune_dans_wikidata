# %% [markdown]
# # La Commune de Paris 1871 en liberté - Faire une requête sur wikidata en Python

# %% [markdown]
# Ce chapitre documente un point technique important pour la suite. Il explique comment le code fonctionne, et n'interroge pas la pertinance des choix de la requête. Cela est vu à d'autres moment.
#
# L'exemple est pris sur la recherche des communard·e·s présent·e·s dans Wikidata. L'explication de qu'est ce qu'un·e "communard·e·s présent·e·s dans Wikidata" sera vu plus loin.
#
# ### Méthode
#
# La classe Extraction_wikidata, est une adaption du modèle de réquête en python qui se trouve sur https://query.wikidata.org/
#
# - dans la variable query, il faut copier/coller la requête faite dans query.wikidata.org
# - exécuter les cellules "## 0" à "## 5" comme si dessous afin d'obtenir le résultat dans un dataframe exploitable pour faire des manipulations de données.
#
# Cela est reproductible, et l'est à de nombreuses occurence dans le document, sur plusieurs requêtes.
# Il suffit de changer la valeur de query (en ## 1) puis personnaliser les ##4 et 5 pour obtenir un tableau (dataframe) exploitable.

# %%
# les installations nécessaires
#https://rdflib.github.io/sparqlwrapper/
#!pip install sparqlwrapper
#!pip install seaborn

# %%
## 0 - import
import sys

from SPARQLWrapper import SPARQLWrapper, JSON

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import HTML

# %%
## 1 - les variables
endpoint_url:str = "https://query.wikidata.org/sparql"

# %%
query:str = """SELECT ?communard_ou_communarde ?communard_ou_communardeLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],fr". }
  # ?communard_ou_communarde wdt:P106 wd:Q1780490.
}"""

# %%
## 2 - l'objet
class Extraction_wikidata():
    def __init__(self, endpoint_url:str, query:str):
        self.endpoint_url:str = endpoint_url
        self.query:str = query
        
    def get_results(self, endpoint_url:str, query:str):
        user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
        # TODO adjust user agent; see https://w.wiki/CX6
        sparql = SPARQLWrapper(endpoint_url, agent = user_agent)
        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)
        return sparql.query().convert()
    
    def json_to_df(self, entree):
        #results = sparql.query().convert()
        df_results = pd.json_normalize(entree["results"]["bindings"])
        return df_results
    
    def extraire_et_df(self):
        extract_json = self.get_results(self.endpoint_url, self.query)
        extract_df = self.json_to_df(extract_json)
        return extract_df

# %%
## 3 - instantiation de l'objet et récupération du df
extraction_communard = Extraction_wikidata(endpoint_url, query)
df_communard = extraction_communard.extraire_et_df()

# %%
## 4 - afficher le df voulu
print(df_communard)
# Out:
#     communard_ou_communarde.type              communard_ou_communarde.value  \
# 0                            uri      http://www.wikidata.org/entity/Q20951
# 1                            uri      http://www.wikidata.org/entity/Q34618
# 2                            uri     http://www.wikidata.org/entity/Q184535
# 3                            uri     http://www.wikidata.org/entity/Q216092
# 4                            uri     http://www.wikidata.org/entity/Q257950
# ..                           ...                                        ...
# 305                          uri  http://www.wikidata.org/entity/Q115257385
# 306                          uri  http://www.wikidata.org/entity/Q115257386
# 307                          uri  http://www.wikidata.org/entity/Q115257387
# 308                          uri  http://www.wikidata.org/entity/Q115257388
# 309                          uri  http://www.wikidata.org/entity/Q118198782
#
#     communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 0                                      fr                           literal
# 1                                      fr                           literal
# 2                                      fr                           literal
# 3                                      fr                           literal
# 4                                      fr                           literal
# ..                                    ...                               ...
# 305                                    fr                           literal
# 306                                    fr                           literal
# 307                                    fr                           literal
# 308                                    fr                           literal
# 309                                    fr                           literal
#
#     communard_ou_communardeLabel.value
# 0                        Élisée Reclus
# 1                      Gustave Courbet
# 2                   Sofia Kovalevskaïa
# 3                        Louise Michel
# 4          Auguste-Jean-Marie Vermorel
# ..                                 ...
# 305                       Sophie Graix
# 306                    Joséphine Pratt
# 307                Céline Delvainquier
# 308                 Aimée Delvainquier
# 309                     Michel Sérigné
#
# [310 rows x 5 columns]

# %%
## 5 - quelques statistiques sur le df
#df_communard.describe()

# %%
df_communard_en_html = df_communard.to_html(columns = ['communard_ou_communarde.value', 'communard_ou_communardeLabel.value'])
HTML(df_communard_en_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>communard_ou_communarde.value</th>
#       <th>communard_ou_communardeLabel.value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://www.wikidata.org/entity/Q20951</td>
#       <td>Élisée Reclus</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://www.wikidata.org/entity/Q34618</td>
#       <td>Gustave Courbet</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://www.wikidata.org/entity/Q184535</td>
#       <td>Sofia Kovalevskaïa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://www.wikidata.org/entity/Q216092</td>
#       <td>Louise Michel</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://www.wikidata.org/entity/Q257950</td>
#       <td>Auguste-Jean-Marie Vermorel</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://www.wikidata.org/entity/Q274464</td>
#       <td>Édouard Vaillant</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>http://www.wikidata.org/entity/Q309722</td>
#       <td>Auguste Blanqui</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>http://www.wikidata.org/entity/Q312915</td>
#       <td>Eugène Pottier</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://www.wikidata.org/entity/Q337628</td>
#       <td>Piotr Lavrov</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>http://www.wikidata.org/entity/Q349485</td>
#       <td>Jules Allix</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>http://www.wikidata.org/entity/Q386390</td>
#       <td>Olivier Souêtre</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>http://www.wikidata.org/entity/Q441121</td>
#       <td>Jean-Louis Pindy</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>http://www.wikidata.org/entity/Q454246</td>
#       <td>Nina de Callias</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>http://www.wikidata.org/entity/Q458559</td>
#       <td>André Léo</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>http://www.wikidata.org/entity/Q465213</td>
#       <td>Jarosław Dombrowski</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>http://www.wikidata.org/entity/Q515589</td>
#       <td>Jean Baptiste Clément</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>http://www.wikidata.org/entity/Q517027</td>
#       <td>Gustave Flourens</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>http://www.wikidata.org/entity/Q518827</td>
#       <td>André Gill</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>http://www.wikidata.org/entity/Q520977</td>
#       <td>Charles Beslay</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>http://www.wikidata.org/entity/Q539458</td>
#       <td>Jean Allemane</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>http://www.wikidata.org/entity/Q551597</td>
#       <td>Jules Vallès</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>http://www.wikidata.org/entity/Q551648</td>
#       <td>Jules Dalou</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>http://www.wikidata.org/entity/Q598272</td>
#       <td>Jules Andrieu</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>http://www.wikidata.org/entity/Q621029</td>
#       <td>Charles Delescluze</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>http://www.wikidata.org/entity/Q642060</td>
#       <td>Henri Rochefort</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>http://www.wikidata.org/entity/Q656691</td>
#       <td>Émile Eudes</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>http://www.wikidata.org/entity/Q684449</td>
#       <td>Gustave Paul Cluseret</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>http://www.wikidata.org/entity/Q700018</td>
#       <td>Léo Frankel</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>http://www.wikidata.org/entity/Q726985</td>
#       <td>Walery Wroblewski</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>http://www.wikidata.org/entity/Q744276</td>
#       <td>Jacques Louis Durand</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>http://www.wikidata.org/entity/Q744469</td>
#       <td>Eugène Vermersch</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>http://www.wikidata.org/entity/Q950710</td>
#       <td>Henri Chouteau</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>http://www.wikidata.org/entity/Q955905</td>
#       <td>Auguste Serraillier</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>http://www.wikidata.org/entity/Q1065362</td>
#       <td>Charles Longuet</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>http://www.wikidata.org/entity/Q1117646</td>
#       <td>Charles Lullier</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>http://www.wikidata.org/entity/Q1118848</td>
#       <td>Paschal Grousset</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>http://www.wikidata.org/entity/Q1122778</td>
#       <td>Émile Léopold Clément</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>http://www.wikidata.org/entity/Q1125847</td>
#       <td>Henry Bauër</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>http://www.wikidata.org/entity/Q1959369</td>
#       <td>François Jourde</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>http://www.wikidata.org/entity/Q2008597</td>
#       <td>Anna Jaclard</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>http://www.wikidata.org/entity/Q2015151</td>
#       <td>Benoît Malon</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>http://www.wikidata.org/entity/Q2020304</td>
#       <td>Jules-Paul Johannard</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>http://www.wikidata.org/entity/Q2021981</td>
#       <td>Arthur Ranc</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>http://www.wikidata.org/entity/Q2287435</td>
#       <td>Simon Deutsch</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>http://www.wikidata.org/entity/Q2332848</td>
#       <td>Raoul Rigault</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>http://www.wikidata.org/entity/Q2376768</td>
#       <td>Armand Antoine Jules Arnaud</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>http://www.wikidata.org/entity/Q2383390</td>
#       <td>Gustave Maroteau</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>http://www.wikidata.org/entity/Q2426660</td>
#       <td>Eugène Varlin</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>http://www.wikidata.org/entity/Q2476089</td>
#       <td>Napoléon La Cécilia</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>http://www.wikidata.org/entity/Q2477042</td>
#       <td>Gustave Lefrançais</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>http://www.wikidata.org/entity/Q2512019</td>
#       <td>Père Tanguy</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>http://www.wikidata.org/entity/Q2643165</td>
#       <td>Arthur Arnould</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>http://www.wikidata.org/entity/Q2706181</td>
#       <td>Nathalie Lemel</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>http://www.wikidata.org/entity/Q2707971</td>
#       <td>Élisabeth Dmitrieff</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>http://www.wikidata.org/entity/Q2711077</td>
#       <td>Pierre Vésinier</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>http://www.wikidata.org/entity/Q2754922</td>
#       <td>Amilcare Cipriani</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>http://www.wikidata.org/entity/Q2823036</td>
#       <td>Achille Ballière</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>http://www.wikidata.org/entity/Q2824709</td>
#       <td>Adolf Rozwadowski</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>http://www.wikidata.org/entity/Q2824769</td>
#       <td>Adolphe Assi</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>http://www.wikidata.org/entity/Q2824796</td>
#       <td>Adolphe Clémence</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>http://www.wikidata.org/entity/Q2825426</td>
#       <td>Adèle Esquiros</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>http://www.wikidata.org/entity/Q2826417</td>
#       <td>Agar</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>http://www.wikidata.org/entity/Q2831493</td>
#       <td>Albert Regnard</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>http://www.wikidata.org/entit

# %% [markdown]
# ### Avoir TOUTES les informations sur les communard·e·s

# %% [markdown]
# Cette requête, qui fonctionne comme expliqué ci dessus est importante. Car en plus de charger toutes les personnes concernées (leur label) elle récupére toutes les données liées à leur élément.
#
# Ce dataframe sera ré-utilisé à de nombreuses occasions.
#
# Pour toutes les personnes, chercher les ?p ?q avec gestion des labels.
# Attention : c'est lourd !

# %% [markdown]
# #### Aller chercher les valeurs et les mettre dans un dataframe (df) nommé df_communard_tous_p_q

# %%
query = """SELECT ?communard_ou_communarde ?communard_ou_communardeLabel ?p ?pLabel ?q ?qLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "fr,en".
                         # ?communard_ou_communarde rdfs:label ?communard_ou_communardeLabel.
                         # ?p rdfs:label ?pLabel.
                         # ?q rdfs:label ?qLabel.}
  
  # ?communard_ou_communarde wdt:P106 wd:Q1780490;
                           # ?p ?q. 
}
"""

# %%
extraction_communard_tous_p_q = Extraction_wikidata(endpoint_url, query)
df_communard_tous_p_q = extraction_communard_tous_p_q.extraire_et_df()

# %%
df_communard_tous_p_q
# Out:
#       communard_ou_communarde.type            communard_ou_communarde.value  \
# 0                              uri    http://www.wikidata.org/entity/Q20951
# 1                              uri    http://www.wikidata.org/entity/Q20951
# 2                              uri    http://www.wikidata.org/entity/Q20951
# 3                              uri    http://www.wikidata.org/entity/Q20951
# 4                              uri    http://www.wikidata.org/entity/Q20951
# ...                            ...                                      ...
# 34467                          uri  http://www.wikidata.org/entity/Q3083515
# 34468                          uri  http://www.wikidata.org/entity/Q3083515
# 34469                          uri  http://www.wikidata.org/entity/Q3083515
# 34470                          uri  http://www.wikidata.org/entity/Q3083515
# 34471                          uri  http://www.wikidata.org/entity/Q3083515
#
#       p.type                             p.value  \
# 0        uri           http://schema.org/version
# 1        uri      http://schema.org/dateModified
# 2        uri       http://schema.org/description
# 3        uri       http://schema.org/description
# 4        uri       http://schema.org/description
# ...      ...                                 ...
# 34467    uri  http://www.wikidata.org/prop/P1412
# 34468    uri  http://www.wikidata.org/prop/P1559
# 34469    uri  http://www.wikidata.org/prop/P1596
# 34470    uri  http://www.wikidata.org/prop/P2671
# 34471    uri  http://www.wikidata.org/prop/P4724
#
#                                       q.datatype   q.type  \
# 0       http://www.w3.org/2001/XMLSchema#integer  literal
# 1      http://www.w3.org/2001/XMLSchema#dateTime  literal
# 2                                            NaN  literal
# 3                                            NaN  literal
# 4                                            NaN  literal
# ...                                          ...      ...
# 34467                                        NaN      uri
# 34468                                        NaN      uri
# 34469                                        NaN      uri
# 34470                                        NaN      uri
# 34471                                        NaN      uri
#
#                                                  q.value  \
# 0                                             2264324905
# 1                                   2024-10-23T21:40:18Z
# 2                                         ލިޔުންތެރިއެއް
# 3                             France karimba ŋun nyɛ doo
# 4                       francouzský geograf a anarchista
# ...                                                  ...
# 34467  http://www.wikidata.org/entity/statement/Q3083...
# 34468  http://www.wikidata.org/entity/statement/Q3083...
# 34469  http://www.wikidata.org/entity/statement/Q3083...
# 34470  http://www.wikidata.org/entity/statement/Q3083...
# 34471  http://www.wikidata.org/entity/statement/Q3083...
#
#       communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 0                                        fr                           literal
# 1                                        fr                           literal
# 2                                        fr                           literal
# 3                                        fr                           literal
# 4                                        fr                           literal
# ...                                     ...                               ...
# 34467                                    fr                           literal
# 34468                                    fr                           literal
# 34469                                    fr                           literal
# 34470                                    fr                           literal
# 34471                                    fr                           literal
#
#       communard_ou_communardeLabel.value pLabel.type  \
# 0                          Élisée Reclus     literal
# 1                          Élisée Reclus     literal
# 2                          Élisée Reclus     literal
# 3                          Élisée Reclus     literal
# 4                          Élisée Reclus     literal
# ...                                  ...         ...
# 34467             François-Louis Parisel     literal
# 34468             François-Louis Parisel     literal
# 34469             François-Louis Parisel     literal
# 34470             François-Louis Parisel     literal
# 34471             François-Louis Parisel     literal
#
#                              pLabel.value qLabel.type  \
# 0               http://schema.org/version     literal
# 1          http://schema.org/dateModified     literal
# 2           http://schema.org/description     literal
# 3           http://schema.org/description     literal
# 4           http://schema.org/description     literal
# ...                                   ...         ...
# 34467  http://www.wikidata.org/prop/P1412     literal
# 34468  http://www.wikidata.org/prop/P1559     literal
# 34469  http://www.wikidata.org/prop/P1596     literal
# 34470  http://www.wikidata.org/prop/P2671     literal
# 34471  http://www.wikidata.org/prop/P4724     literal
#
#                                             qLabel.value q.xml:lang  \
# 0                                             2264324905        NaN
# 1                                   2024-10-23T21:40:18Z        NaN
# 2                                         ލިޔުންތެރިއެއް         dv
# 3                             France karimba ŋun nyɛ doo        dag
# 4                       francouzský geograf a anarchista         cs
# ...                                                  ...        ...
# 34467  statement/Q3083515-5A31CF4A-B593-496C-A271-CEA...        NaN
# 34468  statement/Q3083515-6F000457-A1A2-45B7-9209-873...        NaN
# 34469  statement/Q3083515-34979a69-4553-0922-956c-0f4...        NaN
# 34470  statement/Q3083515-D5DCA60C-88FE-4EC8-8F6D-EDE...        NaN
# 34471  statement/Q3083515-90313a08-44ad-31ee-9131-1a5...        NaN
#
#       qLabel.xml:lang
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 34467             NaN
# 34468             NaN
# 34469             NaN
# 34470             NaN
# 34471             NaN
#
# [34472 rows x 16 columns]

# %% [markdown]
# #### Quelques apperçu de travail sur ce df

# %%
#df_communard_tous_p_q.describe()

# %%
df_communard_tous_p_q.columns
# Out:
# Index(['communard_ou_communarde.type', 'communard_ou_communarde.value',
#        'p.type', 'p.value', 'q.datatype', 'q.type', 'q.value',
#        'communard_ou_communardeLabel.xml:lang',
#        'communard_ou_communardeLabel.type',
#        'communard_ou_communardeLabel.value', 'pLabel.type', 'pLabel.value',
#        'qLabel.type', 'qLabel.value', 'q.xml:lang', 'qLabel.xml:lang'],
#       dtype='object')

# %%
df_communard_tous_p_q.tail(50)
# Out:
#       communard_ou_communarde.type            communard_ou_communarde.value  \
# 34422                          uri  http://www.wikidata.org/entity/Q3083515
# 34423                          uri  http://www.wikidata.org/entity/Q3083515
# 34424                          uri  http://www.wikidata.org/entity/Q3083515
# 34425                          uri  http://www.wikidata.org/entity/Q3083515
# 34426                          uri  http://www.wikidata.org/entity/Q3083515
# 34427                          uri  http://www.wikidata.org/entity/Q3083515
# 34428                          uri  http://www.wikidata.org/entity/Q3083515
# 34429                          uri  http://www.wikidata.org/entity/Q3083515
# 34430                          uri  http://www.wikidata.org/entity/Q3083515
# 34431                          uri  http://www.wikidata.org/entity/Q3083515
# 34432                          uri  http://www.wikidata.org/entity/Q3083515
# 34433                          uri  http://www.wikidata.org/entity/Q3083515
# 34434                          uri  http://www.wikidata.org/entity/Q3083515
# 34435                          uri  http://www.wikidata.org/entity/Q3083515
# 34436                          uri  http://www.wikidata.org/entity/Q3083515
# 34437                          uri  http://www.wikidata.org/entity/Q3083515
# 34438                          uri  http://www.wikidata.org/entity/Q3083515
# 34439                          uri  http://www.wikidata.org/entity/Q3083515
# 34440                          uri  http://www.wikidata.org/entity/Q3083515
# 34441                          uri  http://www.wikidata.org/entity/Q3083515
# 34442                          uri  http://www.wikidata.org/entity/Q3083515
# 34443                          uri  http://www.wikidata.org/entity/Q3083515
# 34444                          uri  http://www.wikidata.org/entity/Q3083515
# 34445                          uri  http://www.wikidata.org/entity/Q3083515
# 34446                          uri  http://www.wikidata.org/entity/Q3083515
# 34447                          uri  http://www.wikidata.org/entity/Q3083515
# 34448                          uri  http://www.wikidata.org/entity/Q3083515
# 34449                          uri  http://www.wikidata.org/entity/Q3083515
# 34450                          uri  http://www.wikidata.org/entity/Q3083515
# 34451                          uri  http://www.wikidata.org/entity/Q3083515
# 34452                          uri  http://www.wikidata.org/entity/Q3083515
# 34453                          uri  http://www.wikidata.org/entity/Q3083515
# 34454                          uri  http://www.wikidata.org/entity/Q3083515
# 34455                          uri  http://www.wikidata.org/entity/Q3083515
# 34456                          uri  http://www.wikidata.org/entity/Q3083515
# 34457                          uri  http://www.wikidata.org/entity/Q3083515
# 34458                          uri  http://www.wikidata.org/entity/Q3083515
# 34459                          uri  http://www.wikidata.org/entity/Q3083515
# 34460                          uri  http://www.wikidata.org/entity/Q3083515
# 34461                          uri  http://www.wikidata.org/entity/Q3083515
# 34462                          uri  http://www.wikidata.org/entity/Q3083515
# 34463                          uri  http://www.wikidata.org/entity/Q3083515
# 34464                          uri  http://www.wikidata.org/entity/Q3083515
# 34465                          uri  http://www.wikidata.org/entity/Q3083515
# 34466                          uri  http://www.wikidata.org/entity/Q3083515
# 34467                          uri  http://www.wikidata.org/entity/Q3083515
# 34468                          uri  http://www.wikidata.org/entity/Q3083515
# 34469                          uri  http://www.wikidata.org/entity/Q3083515
# 34470                          uri  http://www.wikidata.org/entity/Q3083515
# 34471                          uri  http://www.wikidata.org/entity/Q3083515
#
#       p.type                                            p.value  \
# 34422    uri            http://www.wikidata.org/prop/direct/P19
# 34423    uri            http://www.wikidata.org/prop/direct/P20
# 34424    uri            http://www.wikidata.org/prop/direct/P21
# 34425    uri            http://www.wikidata.org/prop/direct/P27
# 34426    uri            http://www.wikidata.org/prop/direct/P31
# 34427    uri            http://www.wikidata.org/prop/direct/P69
# 34428    uri           http://www.wikidata.org/prop/direct/P106
# 34429    uri           http://www.wikidata.org/prop/direct/P106
# 34430    uri           http://www.wikidata.org/prop/direct/P214
# 34431    uri  http://www.wikidata.org/prop/direct-normalized...
# 34432    uri                   http://www.wikidata.org/prop/P19
# 34433    uri                   http://www.wikidata.org/prop/P20
# 34434    uri                   http://www.wikidata.org/prop/P21
# 34435    uri                   http://www.wikidata.org/prop/P27
# 34436    uri                   http://www.wikidata.org/prop/P31
# 34437    uri                   http://www.wikidata.org/prop/P69
# 34438    uri                  http://www.wikidata.org/prop/P106
# 34439    uri                  http://www.wikidata.org/prop/P106
# 34440    uri                  http://www.wikidata.org/prop/P214
# 34441    uri           http://www.wikidata.org/prop/direct/P268
# 34442    uri           http://www.wikidata.org/prop/direct/P269
# 34443    uri           http://www.wikidata.org/prop/direct/P463
# 34444    uri           http://www.wikidata.org/prop/direct/P463
# 34445    uri           http://www.wikidata.org/prop/direct/P569
# 34446    uri           http://www.wikidata.org/prop/direct/P570
# 34447    uri           http://www.wikidata.org/prop/direct/P607
# 34448    uri           http://www.wikidata.org/prop/direct/P734
# 34449    uri           http://www.wikidata.org/prop/direct/P735
# 34450    uri          http://www.wikidata.org/prop/direct/P1412
# 34451    uri          http://www.wikidata.org/prop/direct/P1559
# 34452    uri          http://www.wikidata.org/prop/direct/P1596
# 34453    uri          http://www.wikidata.org/prop/direct/P2671
# 34454    uri          http://www.wikidata.org/prop/direct/P4724
# 34455    uri  http://www.wikidata.org/prop/direct-normalized...
# 34456    uri  http://www.wikidata.org/prop/direct-normalized...
# 34457    uri  http://www.wikidata.org/prop/direct-normalized...
# 34458    uri                  http://www.wikidata.org/prop/P268
# 34459    uri                  http://www.wikidata.org/prop/P269
# 34460    uri                  http://www.wikidata.org/prop/P463
# 34461    uri                  http://www.wikidata.org/prop/P463
# 34462    uri                  http://www.wikidata.org/prop/P569
# 34463    uri                  http://www.wikidata.org/prop/P570
# 34464    uri                  http://www.wikidata.org/prop/P607
# 34465    uri                  http://www.wikidata.org/prop/P734
# 34466    uri                  http://www.wikidata.org/prop/P735
# 34467    uri                 http://www.wikidata.org/prop/P1412
# 34468    uri                 http://www.wikidata.org/prop/P1559
# 34469    uri                 http://www.wikidata.org/prop/P1596
# 34470    uri                 http://www.wikidata.org/prop/P2671
# 34471    uri                 http://www.wikidata.org/prop/P4724
#
#                                       q.datatype   q.type  \
# 34422                                        NaN      uri
# 34423                                        NaN      uri
# 34424                                        NaN      uri
# 34425                                        NaN      uri
# 34426                                        NaN      uri
# 34427                                        NaN      uri
# 34428                                        NaN      uri
# 34429                                        NaN      uri
# 34430                                        NaN  literal
# 34431                                        NaN      uri
# 34432                                        NaN      uri
# 34433                                        NaN      uri
# 34434                                        NaN      uri
# 34435                                        NaN      uri
# 34436                                        NaN      uri
# 34437                                        NaN      uri
# 34438                                        NaN      uri
# 34439                                        NaN      uri
# 34440                                        NaN      uri
# 34441                                        NaN  literal
# 34442                                        NaN  literal
# 34443                                        NaN      uri
# 34444                                        NaN      uri
# 34445  http://www.w3.org/2001/XMLSchema#dateTime  literal
# 34446  http://www.w3.org/2001/XMLSchema#dateTime  literal
# 34447                                        NaN      uri
# 34448                                        NaN      uri
# 34449                                        NaN      uri
# 34450                                        NaN      uri
# 34451                                        NaN  literal
# 34452                                        NaN      uri
# 34453                                        NaN  literal
# 34454                                        NaN  literal
# 34455                                        NaN      uri
# 34456                                        NaN      uri
# 34457                                        NaN      uri
# 34458                                        NaN      uri
# 34459                                        NaN      uri
# 34460                                        NaN      uri
# 34461                                        NaN      uri
# 34462                                        NaN      uri
# 34463                                        NaN      uri
# 34464                                        NaN      uri
# 34465                                        NaN      uri
# 34466                                        NaN      uri
# 34467                                        NaN      uri
# 34468                                        NaN      uri
# 34469                                        NaN      uri
# 34470                                        NaN      uri
# 34471                                        NaN      uri
#
#                                                  q.value  \
# 34422            http://www.wikidata.org/entity/Q3209735
# 34423              http://www.wikidata.org/entity/Q25395
# 34424            http://www.wikidata.org/entity/Q6581097
# 34425                http://www.wikidata.org/entity/Q142
# 34426                  http://www.wikidata.org/entity/Q5
# 34427            http://www.wikidata.org/entity/Q3064295
# 34428              http://www.wikidata.org/entity/Q39631
# 34429            http://www.wikidata.org/entity/Q1780490
# 34430                              259146284394915331471
# 34431         http://viaf.org/viaf/259146284394915331471
# 34432  http://www.wikidata.org/entity/statement/Q3083...
# 34433  http://www.wikidata.org/entity/statement/Q3083...
# 34434  http://www.wikidata.org/entity/statement/Q3083...
# 34435  http://www.wikidata.org/entity/statement/Q3083...
# 34436  http://www.wikidata.org/entity/statement/Q3083...
# 34437  http://www.wikidata.org/entity/statement/Q3083...
# 34438  http://www.wikidata.org/entity/statement/Q3083...
# 34439  http://www.wikidata.org/entity/statement/Q3083...
# 34440  http://www.wikidata.org/entity/statement/Q3083...
# 34441                                          107830869
# 34442                                          192805584
# 34443            http://www.wikidata.org/entity/Q2408404
# 34444            http://www.wikidata.org/entity/Q2993765
# 34445                               1841-10-17T00:00:00Z
# 34446                               1877-07-05T00:00:00Z
# 34447             http://www.wikidata.org/entity/Q690489
# 34448           http://www.wikidata.org/entity/Q65111781
# 34449            http://www.wikidata.org/entity/Q1166840
# 34450                http://www.wikidata.org/entity/Q150
# 34451                             François-Louis Parisel
# 34452               http://www.wikidata.org/entity/Q8454
# 34453                                        /g/121lyszb
# 34454                                              67547
# 34455    http://data.bnf.fr/ark:/12148/cb107830869#about
# 34456                   http://www.idref.fr/192805584/id
# 34457                          http://g.co/kg/g/121lyszb
# 34458  http://www.wikidata.org/entity/statement/Q3083...
# 34459  http://www.wikidata.org/entity/statement/Q3083...
# 34460  http://www.wikidata.org/entity/statement/Q3083...
# 34461  http://www.wikidata.org/entity/statement/Q3083...
# 34462  http://www.wikidata.org/entity/statement/Q3083...
# 34463  http://www.wikidata.org/entity/statement/Q3083...
# 34464  http://www.wikidata.org/entity/statement/Q3083...
# 34465  http://www.wikidata.org/entity/statement/Q3083...
# 34466  http://www.wikidata.org/entity/statement/Q3083...
# 34467  http://www.wikidata.org/entity/statement/Q3083...
# 34468  http://www.wikidata.org/entity/statement/Q3083...
# 34469  http://www.wikidata.org/entity/statement/Q3083...
# 34470  http://www.wikidata.org/entity/statement/Q3083...
# 34471  http://www.wikidata.org/entity/statement/Q3083...
#
#       communard_ou_communardeLabel.xml:lang communard_ou_communardeLabel.type  \
# 34422                                    fr                           literal
# 34423                                    fr                           literal
# 34424                                    fr                           literal
# 34425                                    fr                           literal
# 34426                                    fr                           literal
# 34427                                    fr                           literal
# 34428                                    fr                           literal
# 34429                                    fr                           literal
# 34430                                    fr                           literal
# 34431                                    fr                           literal
# 34432                                    fr                           literal
# 34433                                    fr                           literal
# 34434                                    fr                           literal
# 34435                                    fr                           literal
# 34436                                    fr                           literal
# 34437                                    fr                           literal
# 34438                                    fr                           literal
# 34439                                    fr                           literal
# 34440                                    fr                           literal
# 34441                                    fr                           literal
# 34442                                    fr                           literal
# 34443                                    fr                           literal
# 34444                                    fr                           literal
# 34445                                    fr                           literal
# 34446                                    fr                           literal
# 34447                                    fr                           literal
# 34448                                    fr                           literal
# 34449                                    fr                           literal
# 34450                                    fr                           literal
# 34451                                    fr                           literal
# 34452                                    fr                           literal
# 34453                                    fr                           literal
# 34454                                    fr                           literal
# 34455                                    fr                           literal
# 34456                                    fr                           literal
# 34457                                    fr                           literal
# 34458                                    fr                           literal
# 34459                                    fr                           literal
# 34460                                    fr                           literal
# 34461                                    fr                           literal
# 34462                                    fr                           literal
# 34463                                    fr                           literal
# 34464                                    fr                           literal
# 34465                                    fr                           literal
# 34466                                    fr                           literal
# 34467                                    fr                           literal
# 34468                                    fr                           literal
# 34469                                    fr                           literal
# 34470                                    fr                           literal
# 34471                                    fr                           literal
#
#       communard_ou_communardeLabel.value pLabel.type  \
# 34422             François-Louis Parisel     literal
# 34423             François-Louis Parisel     literal
# 34424             François-Louis Parisel     literal
# 34425             François-Louis Parisel     literal
# 34426             François-Louis Parisel     literal
# 34427             François-Louis Parisel     literal
# 34428             François-Louis Parisel     literal
# 34429             François-Louis Parisel     literal
# 34430             François-Louis Parisel     literal
# 34431             François-Louis Parisel     literal
# 34432             François-Louis Parisel     literal
# 34433             François-Louis Parisel     literal
# 34434             François-Louis Parisel     literal
# 34435             François-Louis Parisel     literal
# 34436             François-Louis Parisel     literal
# 34437             François-Louis Parisel     literal
# 34438             François-Louis Parisel     literal
# 34439             François-Louis Parisel     literal
# 34440             François-Louis Parisel     literal
# 34441             François-Louis Parisel     literal
# 34442             François-Louis Parisel     literal
# 34443             François-Louis Parisel     literal
# 34444             François-Louis Parisel     literal
# 34445             François-Louis Parisel     literal
# 34446             François-Louis Parisel     literal
# 34447             François-Louis Parisel     literal
# 34448             François-Louis Parisel     literal
# 34449             François-Louis Parisel     literal
# 34450             François-Louis Parisel     literal
# 34451             François-Louis Parisel     literal
# 34452             François-Louis Parisel     literal
# 34453             François-Louis Parisel     literal
# 34454             François-Louis Parisel     literal
# 34455             François-Louis Parisel     literal
# 34456             François-Louis Parisel     literal
# 34457             François-Louis Parisel     literal
# 34458             François-Louis Parisel     literal
# 34459             François-Louis Parisel     literal
# 34460             François-Louis Parisel     literal
# 34461             François-Louis Parisel     literal
# 34462             François-Louis Parisel     literal
# 34463             François-Louis Parisel     literal
# 34464             François-Louis Parisel     literal
# 34465             François-Louis Parisel     literal
# 34466             François-Louis Parisel     literal
# 34467             François-Louis Parisel     literal
# 34468             François-Louis Parisel     literal
# 34469             François-Louis Parisel     literal
# 34470             François-Louis Parisel     literal
# 34471             François-Louis Parisel     literal
#
#                                             pLabel.value qLabel.type  \
# 34422            http://www.wikidata.org/prop/direct/P19     literal
# 34423            http://www.wikidata.org/prop/direct/P20     literal
# 34424            http://www.wikidata.org/prop/direct/P21     literal
# 34425            http://www.wikidata.org/prop/direct/P27     literal
# 34426            http://www.wikidata.org/prop/direct/P31     literal
# 34427            http://www.wikidata.org/prop/direct/P69     literal
# 34428           http://www.wikidata.org/prop/direct/P106     literal
# 34429           http://www.wikidata.org/prop/direct/P106     literal
# 34430           http://www.wikidata.org/prop/direct/P214     literal
# 34431  http://www.wikidata.org/prop/direct-normalized...     literal
# 34432                   http://www.wikidata.org/prop/P19     literal
# 34433                   http://www.wikidata.org/prop/P20     literal
# 34434                   http://www.wikidata.org/prop/P21     literal
# 34435                   http://www.wikidata.org/prop/P27     literal
# 34436                   http://www.wikidata.org/prop/P31     literal
# 34437                   http://www.wikidata.org/prop/P69     literal
# 34438                  http://www.wikidata.org/prop/P106     literal
# 34439                  http://www.wikidata.org/prop/P106     literal
# 34440                  http://www.wikidata.org/prop/P214     literal
# 34441           http://www.wikidata.org/prop/direct/P268     literal
# 34442           http://www.wikidata.org/prop/direct/P269     literal
# 34443           http://www.wikidata.org/prop/direct/P463     literal
# 34444           http://www.wikidata.org/prop/direct/P463     literal
# 34445           http://www.wikidata.org/prop/direct/P569     literal
# 34446           http://www.wikidata.org/prop/direct/P570     literal
# 34447           http://www.wikidata.org/prop/direct/P607     literal
# 34448           http://www.wikidata.org/prop/direct/P734     literal
# 34449           http://www.wikidata.org/prop/direct/P735     literal
# 34450          http://www.wikidata.org/prop/direct/P1412     literal
# 34451          http://www.wikidata.org/prop/direct/P1559     literal
# 34452          http://www.wikidata.org/prop/direct/P1596     literal
# 34453          http://www.wikidata.org/prop/direct/P2671     literal
# 34454          http://www.wikidata.org/prop/direct/P4724     literal
# 34455  http://www.wikidata.org/prop/direct-normalized...     literal
# 34456  http://www.wikidata.org/prop/direct-normalized...     literal
# 34457  http://www.wikidata.org/prop/direct-normalized...     literal
# 34458                  http://www.wikidata.org/prop/P268     literal
# 34459                  http://www.wikidata.org/prop/P269     literal
# 34460                  http://www.wikidata.org/prop/P463     literal
# 34461                  http://www.wikidata.org/prop/P463     literal
# 34462                  http://www.wikidata.org/prop/P569     literal
# 34463                  http://www.wikidata.org/prop/P570     literal
# 34464                  http://www.wikidata.org/prop/P607     literal
# 34465                  http://www.wikidata.org/prop/P734     literal
# 34466                  http://www.wikidata.org/prop/P735     literal
# 34467                 http://www.wikidata.org/prop/P1412     literal
# 34468                 http://www.wikidata.org/prop/P1559     literal
# 34469                 http://www.wikidata.org/prop/P1596     literal
# 34470                 http://www.wikidata.org/prop/P2671     literal
# 34471                 http://www.wikidata.org/prop/P4724     literal
#
#                                             qLabel.value q.xml:lang  \
# 34422                                     La Guillotière        NaN
# 34423                                             Newark        NaN
# 34424                                           masculin        NaN
# 34425                                             France        NaN
# 34426                                        être humain        NaN
# 34427                      faculté de pharmacie de Paris        NaN
# 34428                                            médecin        NaN
# 34429                            communard ou communarde        NaN
# 34430                              259146284394915331471        NaN
# 34431         http://viaf.org/viaf/259146284394915331471        NaN
# 34432  statement/Q3083515-7A48871B-4C5F-41F9-B904-418...        NaN
# 34433  statement/Q3083515-22FBE624-062F-4C1F-A514-12C...        NaN
# 34434  statement/Q3083515-5B620F16-9950-4156-A40D-CF0...        NaN
# 34435  statement/Q3083515-762677B4-EA09-4AFA-98B7-01E...        NaN
# 34436  statement/Q3083515-8B9AEA69-22CD-41D2-AB13-06C...        NaN
# 34437  statement/Q3083515-3BD1D430-57D6-401A-B991-86F...        NaN
# 34438  statement/Q3083515-6E75C7C9-33C2-4EF7-B089-915...        NaN
# 34439  statement/Q3083515-705AE074-F103-4964-BB16-23F...        NaN
# 34440  statement/Q3083515-753DCFBF-4C16-453D-8E5B-87D...        NaN
# 34441                                          107830869        NaN
# 34442                                          192805584        NaN
# 34443  Comité central républicain des Vingt arrondiss...        NaN
# 34444                              Conseil de la Commune        NaN
# 34445                               1841-10-17T00:00:00Z        NaN
# 34446                               1877-07-05T00:00:00Z        NaN
# 34447                                     siège de Paris        NaN
# 34448                                            Parisel        NaN
# 34449                                           François        NaN
# 34450                                           français        NaN
# 34451                             François-Louis Parisel         fr
# 34452                                      peine de mort        NaN
# 34453                                        /g/121lyszb        NaN
# 34454                                              67547        NaN
# 34455    http://data.bnf.fr/ark:/12148/cb107830869#about        NaN
# 34456                   http://www.idref.fr/192805584/id        NaN
# 34457                          http://g.co/kg/g/121lyszb        NaN
# 34458  statement/Q3083515-E6CE9EC9-D43C-4B33-B97B-9AF...        NaN
# 34459  statement/Q3083515-E770B155-712E-4D15-94A6-436...        NaN
# 34460  statement/Q3083515-41A97B9B-8C26-439E-9F01-7EB...        NaN
# 34461  statement/Q3083515-C4A3AB5B-3FD5-44F7-B458-ED0...        NaN
# 34462  statement/Q3083515-5731C1D8-8F49-4DA9-A8B2-92D...        NaN
# 34463  statement/Q3083515-7A6B25C6-EABF-4416-83E7-957...        NaN
# 34464  statement/Q3083515-243F2B4A-9280-4113-955F-54C...        NaN
# 34465  statement/Q3083515-CBFB781D-BE32-4C8E-B3A0-061...        NaN
# 34466  statement/Q3083515-37B89689-7FB6-43A0-A728-344...        NaN
# 34467  statement/Q3083515-5A31CF4A-B593-496C-A271-CEA...        NaN
# 34468  statement/Q3083515-6F000457-A1A2-45B7-9209-873...        NaN
# 34469  statement/Q3083515-34979a69-4553-0922-956c-0f4...        NaN
# 34470  statement/Q3083515-D5DCA60C-88FE-4EC8-8F6D-EDE...        NaN
# 34471  statement/Q3083515-90313a08-44ad-31ee-9131-1a5...        NaN
#
#       qLabel.xml:lang
# 34422              fr
# 34423              fr
# 34424              fr
# 34425              fr
# 34426              fr
# 34427              fr
# 34428              fr
# 34429              fr
# 34430             NaN
# 34431             NaN
# 34432             NaN
# 34433             NaN
# 34434             NaN
# 34435             NaN
# 34436             NaN
# 34437             NaN
# 34438             NaN
# 34439             NaN
# 34440             NaN
# 34441             NaN
# 34442             NaN
# 34443              fr
# 34444              fr
# 34445             NaN
# 34446             NaN
# 34447              fr
# 34448              fr
# 34449              fr
# 34450              fr
# 34451             NaN
# 34452              fr
# 34453             NaN
# 34454             NaN
# 34455             NaN
# 34456             NaN
# 34457             NaN
# 34458             NaN
# 34459             NaN
# 34460             NaN
# 34461             NaN
# 34462             NaN
# 34463             NaN
# 34464             NaN
# 34465             NaN
# 34466             NaN
# 34467             NaN
# 34468             NaN
# 34469             NaN
# 34470             NaN
# 34471             NaN

# %% [markdown]
# #### Nettoyer le df et le mettre dans df_tout_sur_tous_communard

# %%
# retirer les colonnes "inutiles"
df_nettoyage_colonne = df_communard_tous_p_q.loc[:,['communard_ou_communarde.value','p.value','q.value','communard_ou_communardeLabel.xml:lang','communard_ou_communardeLabel.value', 'pLabel.value','qLabel.value', 'q.xml:lang']]
# garder le français
df_nettoyage_langue = df_nettoyage_colonne[df_nettoyage_colonne['q.xml:lang'] == ("fr" or "NaN")]

# %%
df_nettoyage_langue.describe()
# Out:
#                  communard_ou_communarde.value  \
# count                                     1074
# unique                                     310
# top     http://www.wikidata.org/entity/Q309722
# freq                                        11
#
#                                            p.value     q.value  \
# count                                         1074        1074
# unique                                          10         774
# top     http://www.w3.org/2000/01/rdf-schema#label  communarde
# freq                                           310          47
#
#        communard_ou_communardeLabel.xml:lang  \
# count                                   1074
# unique                                     1
# top                                       fr
# freq                                    1074
#
#        communard_ou_communardeLabel.value  \
# count                                1074
# unique                                310
# top                       Auguste Blanqui
# freq                                   11
#
#                                       pLabel.value qLabel.value q.xml:lang
# count                                         1074         1074       1074
# unique                                          10          774          1
# top     http://www.w3.org/2000/01/rdf-schema#label   communarde         fr
# freq                                           310           47       1074

# %%
# Avoir un df exploitable pour la suite
df_tout_sur_tous_communard = df_nettoyage_langue

# %% [markdown]
# ## fichiers pythons
# Ces scripts sont ré-écrits dans les fichiers :
# - extraction_wd.py pour faire une requete dans wikidata et obtenir un dataframe à exploiter en Python.
# - extraction_communard1.py pour chercher les informations sur les communard, les mettres dans un dataframe et les analyser en Python

# %% [markdown]
# ## Licence
#
# Ce travail est sous licence libre plus précisement Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International.
#
# Il est fait à partir de données libres (diverse licence) et logiciels ou formats libres.
# Citons python, notebook, makedon, mediawiki...
# J'autorise la diffusion commerciale pour payer les frais de papier si quelqu'an veut le diffuser en version papier.
# Par principe, la licence vous autorise à utiliser ce travail sans m'en informer, juste pour ma curiosité, merci de me le signaler.
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Cette œuvre est mise à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
#
# La version originale du notebook et des fichiers liées sont versionnés et héberger sur github.
# https://github.com/silanoc/commune_dans_wikidata
